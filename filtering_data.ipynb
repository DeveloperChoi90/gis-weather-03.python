# %%
import zipfile
import os
import tempfile
import shutil

def filter_zip(zip_path, should_delete):
    """
    zip_path: 원본 zip 파일 경로
    should_delete: 파일명을 인자로 받아, 삭제할 파일이면 True를 반환하는 함수
    """
    # 임시 파일 생성
    tmp_fd, tmp_path = tempfile.mkstemp(suffix='.zip')
    os.close(tmp_fd)
    
    with zipfile.ZipFile(zip_path, 'r') as zin, \
         zipfile.ZipFile(tmp_path, 'w') as zout:
        for item in zin.infolist():
            # should_delete 함수가 True를 반환하면 해당 파일은 새 압축파일에 추가하지 않음
            if not should_delete(item.filename):
                print(f"Deleting {item.filename}")
                continue
            # 파일 읽어와서 새 압축파일에 기록
            file_data = zin.read(item.filename)
            zout.writestr(item, file_data)
    
    # 원본 파일을 백업하거나 새 파일로 교체 (여기서는 원본 파일을 대체)
    shutil.move(tmp_path, zip_path)
    print("압축파일 업데이트 완료!")

# 예시: 파일명이 '.txt' 확장자로 끝나면 삭제하도록 필터링 함수 정의
def delete_txt_files(filename):
    return filename.endswith('00.csv')

# 사용 예시
zip_file_path = 'D:\\PROJECT\\2025\\01.CarbonMap\\01.Data\\02.Weather\\01_Weather_202307.zip'
filter_zip(zip_file_path, delete_txt_files)
# Out:
# Deleting WEATHER_202307010005.csv
# Deleting WEATHER_202307010010.csv
# Deleting WEATHER_202307010015.csv
# Deleting WEATHER_202307010020.csv
# Deleting WEATHER_202307010025.csv
# Deleting WEATHER_202307010030.csv
# Deleting WEATHER_202307010035.csv
# Deleting WEATHER_202307010040.csv
# Deleting WEATHER_202307010045.csv
# Deleting WEATHER_202307010050.csv
# Deleting WEATHER_202307010055.csv
# Deleting WEATHER_202307010105.csv
# Deleting WEATHER_202307010110.csv
# Deleting WEATHER_202307010115.csv
# Deleting WEATHER_202307010120.csv
# Deleting WEATHER_202307010125.csv
# Deleting WEATHER_202307010130.csv
# Deleting WEATHER_202307010135.csv
# Deleting WEATHER_202307010140.csv
# Deleting WEATHER_202307010145.csv
# Deleting WEATHER_202307010150.csv
# Deleting WEATHER_202307010155.csv
# Deleting WEATHER_202307010205.csv
# Deleting WEATHER_202307010210.csv
# Deleting WEATHER_202307010215.csv
# Deleting WEATHER_202307010220.csv
# Deleting WEATHER_202307010225.csv
# Deleting WEATHER_202307010230.csv
# Deleting WEATHER_202307010235.csv
# Deleting WEATHER_202307010240.csv
# Deleting WEATHER_202307010245.csv
# Deleting WEATHER_202307010250.csv
# Deleting WEATHER_202307010255.csv
# Deleting WEATHER_202307010305.csv
# Deleting WEATHER_202307010310.csv
# Deleting WEATHER_202307010315.csv
# Deleting WEATHER_202307010320.csv
# Deleting WEATHER_202307010325.csv
# Deleting WEATHER_202307010330.csv
# Deleting WEATHER_202307010335.csv
# Deleting WEATHER_202307010340.csv
# Deleting WEATHER_202307010345.csv
# Deleting WEATHER_202307010350.csv
# Deleting WEATHER_202307010355.csv
# Deleting WEATHER_202307010405.csv
# Deleting WEATHER_202307010410.csv
# Deleting WEATHER_202307010415.csv
# Deleting WEATHER_202307010420.csv
# Deleting WEATHER_202307010425.csv
# Deleting WEATHER_202307010430.csv
# Deleting WEATHER_202307010435.csv
# Deleting WEATHER_202307010440.csv
# Deleting WEATHER_202307010445.csv
# Deleting WEATHER_202307010450.csv
# Deleting WEATHER_202307010455.csv
# Deleting WEATHER_202307010505.csv
# Deleting WEATHER_202307010510.csv
# Deleting WEATHER_202307010515.csv
# Deleting WEATHER_202307010520.csv
# Deleting WEATHER_202307010525.csv
# Deleting WEATHER_202307010530.csv
# Deleting WEATHER_202307010535.csv
# Deleting WEATHER_202307010540.csv
# Deleting WEATHER_202307010545.csv
# Deleting WEATHER_202307010550.csv
# Deleting WEATHER_202307010555.csv
# Deleting WEATHER_202307010605.csv
# Deleting WEATHER_202307010610.csv
# Deleting WEATHER_202307010615.csv
# Deleting WEATHER_202307010620.csv
# Deleting WEATHER_202307010625.csv
# Deleting WEATHER_202307010630.csv
# Deleting WEATHER_202307010635.csv
# Deleting WEATHER_202307010640.csv
# Deleting WEATHER_202307010645.csv
# Deleting WEATHER_202307010650.csv
# Deleting WEATHER_202307010655.csv
# Deleting WEATHER_202307010705.csv
# Deleting WEATHER_202307010710.csv
# Deleting WEATHER_202307010715.csv
# Deleting WEATHER_202307010720.csv
# Deleting WEATHER_202307010725.csv
# Deleting WEATHER_202307010730.csv
# Deleting WEATHER_202307010735.csv
# Deleting WEATHER_202307010740.csv
# Deleting WEATHER_202307010745.csv
# Deleting WEATHER_202307010750.csv
# Deleting WEATHER_202307010755.csv
# Deleting WEATHER_202307010805.csv
# Deleting WEATHER_202307010810.csv
# Deleting WEATHER_202307010815.csv
# Deleting WEATHER_202307010820.csv
# Deleting WEATHER_202307010825.csv
# Deleting WEATHER_202307010830.csv
# Deleting WEATHER_202307010835.csv
# Deleting WEATHER_202307010840.csv
# Deleting WEATHER_202307010845.csv
# Deleting WEATHER_202307010850.csv
# Deleting WEATHER_202307010855.csv
# Deleting WEATHER_202307010905.csv
# Deleting WEATHER_202307010910.csv
# Deleting WEATHER_202307010915.csv
# Deleting WEATHER_202307010920.csv
# Deleting WEATHER_202307010925.csv
# Deleting WEATHER_202307010930.csv
# Deleting WEATHER_202307010935.csv
# Deleting WEATHER_202307010940.csv
# Deleting WEATHER_202307010945.csv
# Deleting WEATHER_202307010950.csv
# Deleting WEATHER_202307010955.csv
# Deleting WEATHER_202307011005.csv
# Deleting WEATHER_202307011010.csv
# Deleting WEATHER_202307011015.csv
# Deleting WEATHER_202307011020.csv
# Deleting WEATHER_202307011025.csv
# Deleting WEATHER_202307011030.csv
# Deleting WEATHER_202307011035.csv
# Deleting WEATHER_202307011040.csv
# Deleting WEATHER_202307011045.csv
# Deleting WEATHER_202307011050.csv
# Deleting WEATHER_202307011055.csv
# Deleting WEATHER_202307011105.csv
# Deleting WEATHER_202307011110.csv
# Deleting WEATHER_202307011115.csv
# Deleting WEATHER_202307011120.csv
# Deleting WEATHER_202307011125.csv
# Deleting WEATHER_202307011130.csv
# Deleting WEATHER_202307011135.csv
# Deleting WEATHER_202307011140.csv
# Deleting WEATHER_202307011145.csv
# Deleting WEATHER_202307011150.csv
# Deleting WEATHER_202307011155.csv
# Deleting WEATHER_202307011205.csv
# Deleting WEATHER_202307011210.csv
# Deleting WEATHER_202307011215.csv
# Deleting WEATHER_202307011220.csv
# Deleting WEATHER_202307011225.csv
# Deleting WEATHER_202307011230.csv
# Deleting WEATHER_202307011235.csv
# Deleting WEATHER_202307011240.csv
# Deleting WEATHER_202307011245.csv
# Deleting WEATHER_202307011250.csv
# Deleting WEATHER_202307011255.csv
# Deleting WEATHER_202307011305.csv
# Deleting WEATHER_202307011310.csv
# Deleting WEATHER_202307011315.csv
# Deleting WEATHER_202307011320.csv
# Deleting WEATHER_202307011325.csv
# Deleting WEATHER_202307011330.csv
# Deleting WEATHER_202307011335.csv
# Deleting WEATHER_202307011340.csv
# Deleting WEATHER_202307011345.csv
# Deleting WEATHER_202307011350.csv
# Deleting WEATHER_202307011355.csv
# Deleting WEATHER_202307011405.csv
# Deleting WEATHER_202307011410.csv
# Deleting WEATHER_202307011415.csv
# Deleting WEATHER_202307011420.csv
# Deleting WEATHER_202307011425.csv
# Deleting WEATHER_202307011430.csv
# Deleting WEATHER_202307011435.csv
# Deleting WEATHER_202307011440.csv
# Deleting WEATHER_202307011445.csv
# Deleting WEATHER_202307011450.csv
# Deleting WEATHER_202307011455.csv
# Deleting WEATHER_202307011505.csv
# Deleting WEATHER_202307011510.csv
# Deleting WEATHER_202307011515.csv
# Deleting WEATHER_202307011520.csv
# Deleting WEATHER_202307011525.csv
# Deleting WEATHER_202307011530.csv
# Deleting WEATHER_202307011535.csv
# Deleting WEATHER_202307011540.csv
# Deleting WEATHER_202307011545.csv
# Deleting WEATHER_202307011550.csv
# Deleting WEATHER_202307011555.csv
# Deleting WEATHER_202307011605.csv
# Deleting WEATHER_202307011610.csv
# Deleting WEATHER_202307011615.csv
# Deleting WEATHER_202307011620.csv
# Deleting WEATHER_202307011625.csv
# Deleting WEATHER_202307011630.csv
# Deleting WEATHER_202307011635.csv
# Deleting WEATHER_202307011640.csv
# Deleting WEATHER_202307011645.csv
# Deleting WEATHER_202307011650.csv
# Deleting WEATHER_202307011655.csv
# Deleting WEATHER_202307011705.csv
# Deleting WEATHER_202307011710.csv
# Deleting WEATHER_202307011715.csv
# Deleting WEATHER_202307011720.csv
# Deleting WEATHER_202307011725.csv
# Deleting WEATHER_202307011730.csv
# Deleting WEATHER_202307011735.csv
# Deleting WEATHER_202307011740.csv
# Deleting WEATHER_202307011745.csv
# Deleting WEATHER_202307011750.csv
# Deleting WEATHER_202307011755.csv
# Deleting WEATHER_202307011805.csv
# Deleting WEATHER_202307011810.csv
# Deleting WEATHER_202307011815.csv
# Deleting WEATHER_202307011820.csv
# Deleting WEATHER_202307011825.csv
# Deleting WEATHER_202307011830.csv
# Deleting WEATHER_202307011835.csv
# Deleting WEATHER_202307011840.csv
# Deleting WEATHER_202307011845.csv
# Deleting WEATHER_202307011850.csv
# Deleting WEATHER_202307011855.csv
# Deleting WEATHER_202307011905.csv
# Deleting WEATHER_202307011910.csv
# Deleting WEATHER_202307011915.csv
# Deleting WEATHER_202307011920.csv
# Deleting WEATHER_202307011925.csv
# Deleting WEATHER_202307011930.csv
# Deleting WEATHER_202307011935.csv
# Deleting WEATHER_202307011940.csv
# Deleting WEATHER_202307011945.csv
# Deleting WEATHER_202307011950.csv
# Deleting WEATHER_202307011955.csv
# Deleting WEATHER_202307012005.csv
# Deleting WEATHER_202307012010.csv
# Deleting WEATHER_202307012015.csv
# Deleting WEATHER_202307012020.csv
# Deleting WEATHER_202307012025.csv
# Deleting WEATHER_202307012030.csv
# Deleting WEATHER_202307012035.csv
# Deleting WEATHER_202307012040.csv
# Deleting WEATHER_202307012045.csv
# Deleting WEATHER_202307012050.csv
# Deleting WEATHER_202307012055.csv
# Deleting WEATHER_202307012105.csv
# Deleting WEATHER_202307012110.csv
# Deleting WEATHER_202307012115.csv
# Deleting WEATHER_202307012120.csv
# Deleting WEATHER_202307012125.csv
# Deleting WEATHER_202307012130.csv
# Deleting WEATHER_202307012135.csv
# Deleting WEATHER_202307012140.csv
# Deleting WEATHER_202307012145.csv
# Deleting WEATHER_202307012150.csv
# Deleting WEATHER_202307012155.csv
# Deleting WEATHER_202307012205.csv
# Deleting WEATHER_202307012210.csv
# Deleting WEATHER_202307012215.csv
# Deleting WEATHER_202307012220.csv
# Deleting WEATHER_202307012225.csv
# Deleting WEATHER_202307012230.csv
# Deleting WEATHER_202307012235.csv
# Deleting WEATHER_202307012240.csv
# Deleting WEATHER_202307012245.csv
# Deleting WEATHER_202307012250.csv
# Deleting WEATHER_202307012255.csv
# Deleting WEATHER_202307012305.csv
# Deleting WEATHER_202307012310.csv
# Deleting WEATHER_202307012315.csv
# Deleting WEATHER_202307012320.csv
# Deleting WEATHER_202307012325.csv
# Deleting WEATHER_202307012330.csv
# Deleting WEATHER_202307012335.csv
# Deleting WEATHER_202307012340.csv
# Deleting WEATHER_202307012345.csv
# Deleting WEATHER_202307012350.csv
# Deleting WEATHER_202307012355.csv
# Deleting WEATHER_202307020005.csv
# Deleting WEATHER_202307020010.csv
# Deleting WEATHER_202307020015.csv
# Deleting WEATHER_202307020020.csv
# Deleting WEATHER_202307020025.csv
# Deleting WEATHER_202307020030.csv
# Deleting WEATHER_202307020035.csv
# Deleting WEATHER_202307020040.csv
# Deleting WEATHER_202307020045.csv
# Deleting WEATHER_202307020050.csv
# Deleting WEATHER_202307020055.csv
# Deleting WEATHER_202307020105.csv
# Deleting WEATHER_202307020110.csv
# Deleting WEATHER_202307020115.csv
# Deleting WEATHER_202307020120.csv
# Deleting WEATHER_202307020125.csv
# Deleting WEATHER_202307020130.csv
# Deleting WEATHER_202307020135.csv
# Deleting WEATHER_202307020140.csv
# Deleting WEATHER_202307020145.csv
# Deleting WEATHER_202307020150.csv
# Deleting WEATHER_202307020155.csv
# Deleting WEATHER_202307020205.csv
# Deleting WEATHER_202307020210.csv
# Deleting WEATHER_202307020215.csv
# Deleting WEATHER_202307020220.csv
# Deleting WEATHER_202307020225.csv
# Deleting WEATHER_202307020230.csv
# Deleting WEATHER_202307020235.csv
# Deleting WEATHER_202307020240.csv
# Deleting WEATHER_202307020245.csv
# Deleting WEATHER_202307020250.csv
# Deleting WEATHER_202307020255.csv
# Deleting WEATHER_202307020305.csv
# Deleting WEATHER_202307020310.csv
# Deleting WEATHER_202307020315.csv
# Deleting WEATHER_202307020320.csv
# Deleting WEATHER_202307020325.csv
# Deleting WEATHER_202307020330.csv
# Deleting WEATHER_202307020335.csv
# Deleting WEATHER_202307020340.csv
# Deleting WEATHER_202307020345.csv
# Deleting WEATHER_202307020350.csv
# Deleting WEATHER_202307020355.csv
# Deleting WEATHER_202307020405.csv
# Deleting WEATHER_202307020410.csv
# Deleting WEATHER_202307020415.csv
# Deleting WEATHER_202307020420.csv
# Deleting WEATHER_202307020425.csv
# Deleting WEATHER_202307020430.csv
# Deleting WEATHER_202307020435.csv
# Deleting WEATHER_202307020440.csv
# Deleting WEATHER_202307020445.csv
# Deleting WEATHER_202307020450.csv
# Deleting WEATHER_202307020455.csv
# Deleting WEATHER_202307020505.csv
# Deleting WEATHER_202307020510.csv
# Deleting WEATHER_202307020515.csv
# Deleting WEATHER_202307020520.csv
# Deleting WEATHER_202307020525.csv
# Deleting WEATHER_202307020530.csv
# Deleting WEATHER_202307020535.csv
# Deleting WEATHER_202307020540.csv
# Deleting WEATHER_202307020545.csv
# Deleting WEATHER_202307020550.csv
# Deleting WEATHER_202307020555.csv
# Deleting WEATHER_202307020605.csv
# Deleting WEATHER_202307020610.csv
# Deleting WEATHER_202307020615.csv
# Deleting WEATHER_202307020620.csv
# Deleting WEATHER_202307020625.csv
# Deleting WEATHER_202307020630.csv
# Deleting WEATHER_202307020635.csv
# Deleting WEATHER_202307020640.csv
# Deleting WEATHER_202307020645.csv
# Deleting WEATHER_202307020650.csv
# Deleting WEATHER_202307020655.csv
# Deleting WEATHER_202307020705.csv
# Deleting WEATHER_202307020710.csv
# Deleting WEATHER_202307020715.csv
# Deleting WEATHER_202307020720.csv
# Deleting WEATHER_202307020725.csv
# Deleting WEATHER_202307020730.csv
# Deleting WEATHER_202307020735.csv
# Deleting WEATHER_202307020740.csv
# Deleting WEATHER_202307020745.csv
# Deleting WEATHER_202307020750.csv
# Deleting WEATHER_202307020755.csv
# Deleting WEATHER_202307020805.csv
# Deleting WEATHER_202307020810.csv
# Deleting WEATHER_202307020815.csv
# Deleting WEATHER_202307020820.csv
# Deleting WEATHER_202307020825.csv
# Deleting WEATHER_202307020830.csv
# Deleting WEATHER_202307020835.csv
# Deleting WEATHER_202307020840.csv
# Deleting WEATHER_202307020845.csv
# Deleting WEATHER_202307020850.csv
# Deleting WEATHER_202307020855.csv
# Deleting WEATHER_202307020905.csv
# Deleting WEATHER_202307020910.csv
# Deleting WEATHER_202307020915.csv
# Deleting WEATHER_202307020920.csv
# Deleting WEATHER_202307020925.csv
# Deleting WEATHER_202307020930.csv
# Deleting WEATHER_202307020935.csv
# Deleting WEATHER_202307020940.csv
# Deleting WEATHER_202307020945.csv
# Deleting WEATHER_202307020950.csv
# Deleting WEATHER_202307020955.csv
# Deleting WEATHER_202307021005.csv
# Deleting WEATHER_202307021010.csv
# Deleting WEATHER_202307021015.csv
# Deleting WEATHER_202307021020.csv
# Deleting WEATHER_202307021025.csv
# Deleting WEATHER_202307021030.csv
# Deleting WEATHER_202307021035.csv
# Deleting WEATHER_202307021040.csv
# Deleting WEATHER_202307021045.csv
# Deleting WEATHER_202307021050.csv
# Deleting WEATHER_202307021055.csv
# Deleting WEATHER_202307021105.csv
# Deleting WEATHER_202307021110.csv
# Deleting WEATHER_202307021115.csv
# Deleting WEATHER_202307021120.csv
# Deleting WEATHER_202307021125.csv
# Deleting WEATHER_202307021130.csv
# Deleting WEATHER_202307021135.csv
# Deleting WEATHER_202307021140.csv
# Deleting WEATHER_202307021145.csv
# Deleting WEATHER_202307021150.csv
# Deleting WEATHER_202307021155.csv
# Deleting WEATHER_202307021205.csv
# Deleting WEATHER_202307021210.csv
# Deleting WEATHER_202307021215.csv
# Deleting WEATHER_202307021220.csv
# Deleting WEATHER_202307021225.csv
# Deleting WEATHER_202307021230.csv
# Deleting WEATHER_202307021235.csv
# Deleting WEATHER_202307021240.csv
# Deleting WEATHER_202307021245.csv
# Deleting WEATHER_202307021250.csv
# Deleting WEATHER_202307021255.csv
# Deleting WEATHER_202307021305.csv
# Deleting WEATHER_202307021310.csv
# Deleting WEATHER_202307021315.csv
# Deleting WEATHER_202307021320.csv
# Deleting WEATHER_202307021325.csv
# Deleting WEATHER_202307021330.csv
# Deleting WEATHER_202307021335.csv
# Deleting WEATHER_202307021340.csv
# Deleting WEATHER_202307021345.csv
# Deleting WEATHER_202307021350.csv
# Deleting WEATHER_202307021355.csv
# Deleting WEATHER_202307021405.csv
# Deleting WEATHER_202307021410.csv
# Deleting WEATHER_202307021415.csv
# Deleting WEATHER_202307021420.csv
# Deleting WEATHER_202307021425.csv
# Deleting WEATHER_202307021430.csv
# Deleting WEATHER_202307021435.csv
# Deleting WEATHER_202307021440.csv
# Deleting WEATHER_202307021445.csv
# Deleting WEATHER_202307021450.csv
# Deleting WEATHER_202307021455.csv
# Deleting WEATHER_202307021505.csv
# Deleting WEATHER_202307021510.csv
# Deleting WEATHER_202307021515.csv
# Deleting WEATHER_202307021520.csv
# Deleting WEATHER_202307021525.csv
# Deleting WEATHER_202307021530.csv
# Deleting WEATHER_202307021535.csv
# Deleting WEATHER_202307021540.csv
# Deleting WEATHER_202307021545.csv
# Deleting WEATHER_202307021550.csv
# Deleting WEATHER_202307021555.csv
# Deleting WEATHER_202307021605.csv
# Deleting WEATHER_202307021610.csv
# Deleting WEATHER_202307021615.csv
# Deleting WEATHER_202307021620.csv
# Deleting WEATHER_202307021625.csv
# Deleting WEATHER_202307021630.csv
# Deleting WEATHER_202307021635.csv
# Deleting WEATHER_202307021640.csv
# Deleting WEATHER_202307021645.csv
# Deleting WEATHER_202307021650.csv
# Deleting WEATHER_202307021655.csv
# Deleting WEATHER_202307021705.csv
# Deleting WEATHER_202307021710.csv
# Deleting WEATHER_202307021715.csv
# Deleting WEATHER_202307021720.csv
# Deleting WEATHER_202307021725.csv
# Deleting WEATHER_202307021730.csv
# Deleting WEATHER_202307021735.csv
# Deleting WEATHER_202307021740.csv
# Deleting WEATHER_202307021745.csv
# Deleting WEATHER_202307021750.csv
# Deleting WEATHER_202307021755.csv
# Deleting WEATHER_202307021805.csv
# Deleting WEATHER_202307021810.csv
# Deleting WEATHER_202307021815.csv
# Deleting WEATHER_202307021820.csv
# Deleting WEATHER_202307021825.csv
# Deleting WEATHER_202307021830.csv
# Deleting WEATHER_202307021835.csv
# Deleting WEATHER_202307021840.csv
# Deleting WEATHER_202307021845.csv
# Deleting WEATHER_202307021850.csv
# Deleting WEATHER_202307021855.csv
# Deleting WEATHER_202307021905.csv
# Deleting WEATHER_202307021910.csv
# Deleting WEATHER_202307021915.csv
# Deleting WEATHER_202307021920.csv
# Deleting WEATHER_202307021925.csv
# Deleting WEATHER_202307021930.csv
# Deleting WEATHER_202307021935.csv
# Deleting WEATHER_202307021940.csv
# Deleting WEATHER_202307021945.csv
# Deleting WEATHER_202307021950.csv
# Deleting WEATHER_202307021955.csv
# Deleting WEATHER_202307022005.csv
# Deleting WEATHER_202307022010.csv
# Deleting WEATHER_202307022015.csv
# Deleting WEATHER_202307022020.csv
# Deleting WEATHER_202307022025.csv
# Deleting WEATHER_202307022030.csv
# Deleting WEATHER_202307022035.csv
# Deleting WEATHER_202307022040.csv
# Deleting WEATHER_202307022045.csv
# Deleting WEATHER_202307022050.csv
# Deleting WEATHER_202307022055.csv
# Deleting WEATHER_202307022105.csv
# Deleting WEATHER_202307022110.csv
# Deleting WEATHER_202307022115.csv
# Deleting WEATHER_202307022120.csv
# Deleting WEATHER_202307022125.csv
# Deleting WEATHER_202307022130.csv
# Deleting WEATHER_202307022135.csv
# Deleting WEATHER_202307022140.csv
# Deleting WEATHER_202307022145.csv
# Deleting WEATHER_202307022150.csv
# Deleting WEATHER_202307022155.csv
# Deleting WEATHER_202307022205.csv
# Deleting WEATHER_202307022210.csv
# Deleting WEATHER_202307022215.csv
# Deleting WEATHER_202307022220.csv
# Deleting WEATHER_202307022225.csv
# Deleting WEATHER_202307022230.csv
# Deleting WEATHER_202307022235.csv
# Deleting WEATHER_202307022240.csv
# Deleting WEATHER_202307022245.csv
# Deleting WEATHER_202307022250.csv
# Deleting WEATHER_202307022255.csv
# Deleting WEATHER_202307022305.csv
# Deleting WEATHER_202307022310.csv
# Deleting WEATHER_202307022315.csv
# Deleting WEATHER_202307022320.csv
# Deleting WEATHER_202307022325.csv
# Deleting WEATHER_202307022330.csv
# Deleting WEATHER_202307022335.csv
# Deleting WEATHER_202307022340.csv
# Deleting WEATHER_202307022345.csv
# Deleting WEATHER_202307022350.csv
# Deleting WEATHER_202307022355.csv
# Deleting WEATHER_202307030005.csv
# Deleting WEATHER_202307030010.csv
# Deleting WEATHER_202307030015.csv
# Deleting WEATHER_202307030020.csv
# Deleting WEATHER_202307030025.csv
# Deleting WEATHER_202307030030.csv
# Deleting WEATHER_202307030035.csv
# Deleting WEATHER_202307030040.csv
# Deleting WEATHER_202307030045.csv
# Deleting WEATHER_202307030050.csv
# Deleting WEATHER_202307030055.csv
# Deleting WEATHER_202307030105.csv
# Deleting WEATHER_202307030110.csv
# Deleting WEATHER_202307030115.csv
# Deleting WEATHER_202307030120.csv
# Deleting WEATHER_202307030125.csv
# Deleting WEATHER_202307030130.csv
# Deleting WEATHER_202307030135.csv
# Deleting WEATHER_202307030140.csv
# Deleting WEATHER_202307030145.csv
# Deleting WEATHER_202307030150.csv
# Deleting WEATHER_202307030155.csv
# Deleting WEATHER_202307030205.csv
# Deleting WEATHER_202307030210.csv
# Deleting WEATHER_202307030215.csv
# Deleting WEATHER_202307030220.csv
# Deleting WEATHER_202307030225.csv
# Deleting WEATHER_202307030230.csv
# Deleting WEATHER_202307030235.csv
# Deleting WEATHER_202307030240.csv
# Deleting WEATHER_202307030245.csv
# Deleting WEATHER_202307030250.csv
# Deleting WEATHER_202307030255.csv
# Deleting WEATHER_202307030305.csv
# Deleting WEATHER_202307030310.csv
# Deleting WEATHER_202307030315.csv
# Deleting WEATHER_202307030320.csv
# Deleting WEATHER_202307030325.csv
# Deleting WEATHER_202307030330.csv
# Deleting WEATHER_202307030335.csv
# Deleting WEATHER_202307030340.csv
# Deleting WEATHER_202307030345.csv
# Deleting WEATHER_202307030350.csv
# Deleting WEATHER_202307030355.csv
# Deleting WEATHER_202307030405.csv
# Deleting WEATHER_202307030410.csv
# Deleting WEATHER_202307030415.csv
# Deleting WEATHER_202307030420.csv
# Deleting WEATHER_202307030425.csv
# Deleting WEATHER_202307030430.csv
# Deleting WEATHER_202307030435.csv
# Deleting WEATHER_202307030440.csv
# Deleting WEATHER_202307030445.csv
# Deleting WEATHER_202307030450.csv
# Deleting WEATHER_202307030455.csv
# Deleting WEATHER_202307030505.csv
# Deleting WEATHER_202307030510.csv
# Deleting WEATHER_202307030515.csv
# Deleting WEATHER_202307030520.csv
# Deleting WEATHER_202307030525.csv
# Deleting WEATHER_202307030530.csv
# Deleting WEATHER_202307030535.csv
# Deleting WEATHER_202307030540.csv
# Deleting WEATHER_202307030545.csv
# Deleting WEATHER_202307030550.csv
# Deleting WEATHER_202307030555.csv
# Deleting WEATHER_202307030605.csv
# Deleting WEATHER_202307030610.csv
# Deleting WEATHER_202307030615.csv
# Deleting WEATHER_202307030620.csv
# Deleting WEATHER_202307030625.csv
# Deleting WEATHER_202307030630.csv
# Deleting WEATHER_202307030635.csv
# Deleting WEATHER_202307030640.csv
# Deleting WEATHER_202307030645.csv
# Deleting WEATHER_202307030650.csv
# Deleting WEATHER_202307030655.csv
# Deleting WEATHER_202307030705.csv
# Deleting WEATHER_202307030710.csv
# Deleting WEATHER_202307030715.csv
# Deleting WEATHER_202307030720.csv
# Deleting WEATHER_202307030725.csv
# Deleting WEATHER_202307030730.csv
# Deleting WEATHER_202307030735.csv
# Deleting WEATHER_202307030740.csv
# Deleting WEATHER_202307030745.csv
# Deleting WEATHER_202307030750.csv
# Deleting WEATHER_202307030755.csv
# Deleting WEATHER_202307030805.csv
# Deleting WEATHER_202307030810.csv
# Deleting WEATHER_202307030815.csv
# Deleting WEATHER_202307030820.csv
# Deleting WEATHER_202307030825.csv
# Deleting WEATHER_202307030830.csv
# Deleting WEATHER_202307030835.csv
# Deleting WEATHER_202307030840.csv
# Deleting WEATHER_202307030845.csv
# Deleting WEATHER_202307030850.csv
# Deleting WEATHER_202307030855.csv
# Deleting WEATHER_202307030905.csv
# Deleting WEATHER_202307030910.csv
# Deleting WEATHER_202307030915.csv
# Deleting WEATHER_202307030920.csv
# Deleting WEATHER_202307030925.csv
# Deleting WEATHER_202307030930.csv
# Deleting WEATHER_202307030935.csv
# Deleting WEATHER_202307030940.csv
# Deleting WEATHER_202307030945.csv
# Deleting WEATHER_202307030950.csv
# Deleting WEATHER_202307030955.csv
# Deleting WEATHER_202307031005.csv
# Deleting WEATHER_202307031010.csv
# Deleting WEATHER_202307031015.csv
# Deleting WEATHER_202307031020.csv
# Deleting WEATHER_202307031025.csv
# Deleting WEATHER_202307031030.csv
# Deleting WEATHER_202307031035.csv
# Deleting WEATHER_202307031040.csv
# Deleting WEATHER_202307031045.csv
# Deleting WEATHER_202307031050.csv
# Deleting WEATHER_202307031055.csv
# Deleting WEATHER_202307031105.csv
# Deleting WEATHER_202307031110.csv
# Deleting WEATHER_202307031115.csv
# Deleting WEATHER_202307031120.csv
# Deleting WEATHER_202307031125.csv
# Deleting WEATHER_202307031130.csv
# Deleting WEATHER_202307031135.csv
# Deleting WEATHER_202307031140.csv
# Deleting WEATHER_202307031145.csv
# Deleting WEATHER_202307031150.csv
# Deleting WEATHER_202307031155.csv
# Deleting WEATHER_202307031205.csv
# Deleting WEATHER_202307031210.csv
# Deleting WEATHER_202307031215.csv
# Deleting WEATHER_202307031220.csv
# Deleting WEATHER_202307031225.csv
# Deleting WEATHER_202307031230.csv
# Deleting WEATHER_202307031235.csv
# Deleting WEATHER_202307031240.csv
# Deleting WEATHER_202307031245.csv
# Deleting WEATHER_202307031250.csv
# Deleting WEATHER_202307031255.csv
# Deleting WEATHER_202307031305.csv
# Deleting WEATHER_202307031310.csv
# Deleting WEATHER_202307031315.csv
# Deleting WEATHER_202307031320.csv
# Deleting WEATHER_202307031325.csv
# Deleting WEATHER_202307031330.csv
# Deleting WEATHER_202307031335.csv
# Deleting WEATHER_202307031340.csv
# Deleting WEATHER_202307031345.csv
# Deleting WEATHER_202307031350.csv
# Deleting WEATHER_202307031355.csv
# Deleting WEATHER_202307031405.csv
# Deleting WEATHER_202307031410.csv
# Deleting WEATHER_202307031415.csv
# Deleting WEATHER_202307031420.csv
# Deleting WEATHER_202307031425.csv
# Deleting WEATHER_202307031430.csv
# Deleting WEATHER_202307031435.csv
# Deleting WEATHER_202307031440.csv
# Deleting WEATHER_202307031445.csv
# Deleting WEATHER_202307031450.csv
# Deleting WEATHER_202307031455.csv
# Deleting WEATHER_202307031505.csv
# Deleting WEATHER_202307031510.csv
# Deleting WEATHER_202307031515.csv
# Deleting WEATHER_202307031520.csv
# Deleting WEATHER_202307031525.csv
# Deleting WEATHER_202307031530.csv
# Deleting WEATHER_202307031535.csv
# Deleting WEATHER_202307031540.csv
# Deleting WEATHER_202307031545.csv
# Deleting WEATHER_202307031550.csv
# Deleting WEATHER_202307031555.csv
# Deleting WEATHER_202307031605.csv
# Deleting WEATHER_202307031610.csv
# Deleting WEATHER_202307031615.csv
# Deleting WEATHER_202307031620.csv
# Deleting WEATHER_202307031625.csv
# Deleting WEATHER_202307031630.csv
# Deleting WEATHER_202307031635.csv
# Deleting WEATHER_202307031640.csv
# Deleting WEATHER_202307031645.csv
# Deleting WEATHER_202307031650.csv
# Deleting WEATHER_202307031655.csv
# Deleting WEATHER_202307031705.csv
# Deleting WEATHER_202307031710.csv
# Deleting WEATHER_202307031715.csv
# Deleting WEATHER_202307031720.csv
# Deleting WEATHER_202307031725.csv
# Deleting WEATHER_202307031730.csv
# Deleting WEATHER_202307031735.csv
# Deleting WEATHER_202307031740.csv
# Deleting WEATHER_202307031745.csv
# Deleting WEATHER_202307031750.csv
# Deleting WEATHER_202307031755.csv
# Deleting WEATHER_202307031805.csv
# Deleting WEATHER_202307031810.csv
# Deleting WEATHER_202307031815.csv
# Deleting WEATHER_202307031820.csv
# Deleting WEATHER_202307031825.csv
# Deleting WEATHER_202307031830.csv
# Deleting WEATHER_202307031835.csv
# Deleting WEATHER_202307031840.csv
# Deleting WEATHER_202307031845.csv
# Deleting WEATHER_202307031850.csv
# Deleting WEATHER_202307031855.csv
# Deleting WEATHER_202307031905.csv
# Deleting WEATHER_202307031910.csv
# Deleting WEATHER_202307031915.csv
# Deleting WEATHER_202307031920.csv
# Deleting WEATHER_202307031925.csv
# Deleting WEATHER_202307031930.csv
# Deleting WEATHER_202307031935.csv
# Deleting WEATHER_202307031940.csv
# Deleting WEATHER_202307031945.csv
# Deleting WEATHER_202307031950.csv
# Deleting WEATHER_202307031955.csv
# Deleting WEATHER_202307032005.csv
# Deleting WEATHER_202307032010.csv
# Deleting WEATHER_202307032015.csv
# Deleting WEATHER_202307032020.csv
# Deleting WEATHER_202307032025.csv
# Deleting WEATHER_202307032030.csv
# Deleting WEATHER_202307032035.csv
# Deleting WEATHER_202307032040.csv
# Deleting WEATHER_202307032045.csv
# Deleting WEATHER_202307032050.csv
# Deleting WEATHER_202307032055.csv
# Deleting WEATHER_202307032105.csv
# Deleting WEATHER_202307032110.csv
# Deleting WEATHER_202307032115.csv
# Deleting WEATHER_202307032120.csv
# Deleting WEATHER_202307032125.csv
# Deleting WEATHER_202307032130.csv
# Deleting WEATHER_202307032135.csv
# Deleting WEATHER_202307032140.csv
# Deleting WEATHER_202307032145.csv
# Deleting WEATHER_202307032150.csv
# Deleting WEATHER_202307032155.csv
# Deleting WEATHER_202307032205.csv
# Deleting WEATHER_202307032210.csv
# Deleting WEATHER_202307032215.csv
# Deleting WEATHER_202307032220.csv
# Deleting WEATHER_202307032225.csv
# Deleting WEATHER_202307032230.csv
# Deleting WEATHER_202307032235.csv
# Deleting WEATHER_202307032240.csv
# Deleting WEATHER_202307032245.csv
# Deleting WEATHER_202307032250.csv
# Deleting WEATHER_202307032255.csv
# Deleting WEATHER_202307032305.csv
# Deleting WEATHER_202307032310.csv
# Deleting WEATHER_202307032315.csv
# Deleting WEATHER_202307032320.csv
# Deleting WEATHER_202307032325.csv
# Deleting WEATHER_202307032330.csv
# Deleting WEATHER_202307032335.csv
# Deleting WEATHER_202307032340.csv
# Deleting WEATHER_202307032345.csv
# Deleting WEATHER_202307032350.csv
# Deleting WEATHER_202307032355.csv
# Deleting WEATHER_202307040005.csv
# Deleting WEATHER_202307040010.csv
# Deleting WEATHER_202307040015.csv
# Deleting WEATHER_202307040020.csv
# Deleting WEATHER_202307040025.csv
# Deleting WEATHER_202307040030.csv
# Deleting WEATHER_202307040035.csv
# Deleting WEATHER_202307040040.csv
# Deleting WEATHER_202307040045.csv
# Deleting WEATHER_202307040050.csv
# Deleting WEATHER_202307040055.csv
# Deleting WEATHER_202307040105.csv
# Deleting WEATHER_202307040110.csv
# Deleting WEATHER_202307040115.csv
# Deleting WEATHER_202307040120.csv
# Deleting WEATHER_202307040125.csv
# Deleting WEATHER_202307040130.csv
# Deleting WEATHER_202307040135.csv
# Deleting WEATHER_202307040140.csv
# Deleting WEATHER_202307040145.csv
# Deleting WEATHER_202307040150.csv
# Deleting WEATHER_202307040155.csv
# Deleting WEATHER_202307040205.csv
# Deleting WEATHER_202307040210.csv
# Deleting WEATHER_202307040215.csv
# Deleting WEATHER_202307040220.csv
# Deleting WEATHER_202307040225.csv
# Deleting WEATHER_202307040230.csv
# Deleting WEATHER_202307040235.csv
# Deleting WEATHER_202307040240.csv
# Deleting WEATHER_202307040245.csv
# Deleting WEATHER_202307040250.csv
# Deleting WEATHER_202307040255.csv
# Deleting WEATHER_202307040305.csv
# Deleting WEATHER_202307040310.csv
# Deleting WEATHER_202307040315.csv
# Deleting WEATHER_202307040320.csv
# Deleting WEATHER_202307040325.csv
# Deleting WEATHER_202307040330.csv
# Deleting WEATHER_202307040335.csv
# Deleting WEATHER_202307040340.csv
# Deleting WEATHER_202307040345.csv
# Deleting WEATHER_202307040350.csv
# Deleting WEATHER_202307040355.csv
# Deleting WEATHER_202307040405.csv
# Deleting WEATHER_202307040410.csv
# Deleting WEATHER_202307040415.csv
# Deleting WEATHER_202307040420.csv
# Deleting WEATHER_202307040425.csv
# Deleting WEATHER_202307040430.csv
# Deleting WEATHER_202307040435.csv
# Deleting WEATHER_202307040440.csv
# Deleting WEATHER_202307040445.csv
# Deleting WEATHER_202307040450.csv
# Deleting WEATHER_202307040455.csv
# Deleting WEATHER_202307040505.csv
# Deleting WEATHER_202307040510.csv
# Deleting WEATHER_202307040515.csv
# Deleting WEATHER_202307040520.csv
# Deleting WEATHER_202307040525.csv
# Deleting WEATHER_202307040530.csv
# Deleting WEATHER_202307040535.csv
# Deleting WEATHER_202307040540.csv
# Deleting WEATHER_202307040545.csv
# Deleting WEATHER_202307040550.csv
# Deleting WEATHER_202307040555.csv
# Deleting WEATHER_202307040605.csv
# Deleting WEATHER_202307040610.csv
# Deleting WEATHER_202307040615.csv
# Deleting WEATHER_202307040620.csv
# Deleting WEATHER_202307040625.csv
# Deleting WEATHER_202307040630.csv
# Deleting WEATHER_202307040635.csv
# Deleting WEATHER_202307040640.csv
# Deleting WEATHER_202307040645.csv
# Deleting WEATHER_202307040650.csv
# Deleting WEATHER_202307040655.csv
# Deleting WEATHER_202307040705.csv
# Deleting WEATHER_202307040710.csv
# Deleting WEATHER_202307040715.csv
# Deleting WEATHER_202307040720.csv
# Deleting WEATHER_202307040725.csv
# Deleting WEATHER_202307040730.csv
# Deleting WEATHER_202307040735.csv
# Deleting WEATHER_202307040740.csv
# Deleting WEATHER_202307040745.csv
# Deleting WEATHER_202307040750.csv
# Deleting WEATHER_202307040755.csv
# Deleting WEATHER_202307040805.csv
# Deleting WEATHER_202307040810.csv
# Deleting WEATHER_202307040815.csv
# Deleting WEATHER_202307040820.csv
# Deleting WEATHER_202307040825.csv
# Deleting WEATHER_202307040830.csv
# Deleting WEATHER_202307040835.csv
# Deleting WEATHER_202307040840.csv
# Deleting WEATHER_202307040845.csv
# Deleting WEATHER_202307040850.csv
# Deleting WEATHER_202307040855.csv
# Deleting WEATHER_202307040905.csv
# Deleting WEATHER_202307040910.csv
# Deleting WEATHER_202307040915.csv
# Deleting WEATHER_202307040920.csv
# Deleting WEATHER_202307040925.csv
# Deleting WEATHER_202307040930.csv
# Deleting WEATHER_202307040935.csv
# Deleting WEATHER_202307040940.csv
# Deleting WEATHER_202307040945.csv
# Deleting WEATHER_202307040950.csv
# Deleting WEATHER_202307040955.csv
# Deleting WEATHER_202307041005.csv
# Deleting WEATHER_202307041010.csv
# Deleting WEATHER_202307041015.csv
# Deleting WEATHER_202307041020.csv
# Deleting WEATHER_202307041025.csv
# Deleting WEATHER_202307041030.csv
# Deleting WEATHER_202307041035.csv
# Deleting WEATHER_202307041040.csv
# Deleting WEATHER_202307041045.csv
# Deleting WEATHER_202307041050.csv
# Deleting WEATHER_202307041055.csv
# Deleting WEATHER_202307041105.csv
# Deleting WEATHER_202307041110.csv
# Deleting WEATHER_202307041115.csv
# Deleting WEATHER_202307041120.csv
# Deleting WEATHER_202307041125.csv
# Deleting WEATHER_202307041130.csv
# Deleting WEATHER_202307041135.csv
# Deleting WEATHER_202307041140.csv
# Deleting WEATHER_202307041145.csv
# Deleting WEATHER_202307041150.csv
# Deleting WEATHER_202307041155.csv
# Deleting WEATHER_202307041205.csv
# Deleting WEATHER_202307041210.csv
# Deleting WEATHER_202307041215.csv
# Deleting WEATHER_202307041220.csv
# Deleting WEATHER_202307041225.csv
# Deleting WEATHER_202307041230.csv
# Deleting WEATHER_202307041235.csv
# Deleting WEATHER_202307041240.csv
# Deleting WEATHER_202307041245.csv
# Deleting WEATHER_202307041250.csv
# Deleting WEATHER_202307041255.csv
# Deleting WEATHER_202307041305.csv
# Deleting WEATHER_202307041310.csv
# Deleting WEATHER_202307041315.csv
# Deleting WEATHER_202307041320.csv
# Deleting WEATHER_202307041325.csv
# Deleting WEATHER_202307041330.csv
# Deleting WEATHER_202307041335.csv
# Deleting WEATHER_202307041340.csv
# Deleting WEATHER_202307041345.csv
# Deleting WEATHER_202307041350.csv
# Deleting WEATHER_202307041355.csv
# Deleting WEATHER_202307041405.csv
# Deleting WEATHER_202307041410.csv
# Deleting WEATHER_202307041415.csv
# Deleting WEATHER_202307041420.csv
# Deleting WEATHER_202307041425.csv
# Deleting WEATHER_202307041430.csv
# Deleting WEATHER_202307041435.csv
# Deleting WEATHER_202307041440.csv
# Deleting WEATHER_202307041445.csv
# Deleting WEATHER_202307041450.csv
# Deleting WEATHER_202307041455.csv
# Deleting WEATHER_202307041505.csv
# Deleting WEATHER_202307041510.csv
# Deleting WEATHER_202307041515.csv
# Deleting WEATHER_202307041520.csv
# Deleting WEATHER_202307041525.csv
# Deleting WEATHER_202307041530.csv
# Deleting WEATHER_202307041535.csv
# Deleting WEATHER_202307041540.csv
# Deleting WEATHER_202307041545.csv
# Deleting WEATHER_202307041550.csv
# Deleting WEATHER_202307041555.csv
# Deleting WEATHER_202307041605.csv
# Deleting WEATHER_202307041610.csv
# Deleting WEATHER_202307041615.csv
# Deleting WEATHER_202307041620.csv
# Deleting WEATHER_202307041625.csv
# Deleting WEATHER_202307041630.csv
# Deleting WEATHER_202307041635.csv
# Deleting WEATHER_202307041640.csv
# Deleting WEATHER_202307041645.csv
# Deleting WEATHER_202307041650.csv
# Deleting WEATHER_202307041655.csv
# Deleting WEATHER_202307041705.csv
# Deleting WEATHER_202307041710.csv
# Deleting WEATHER_202307041715.csv
# Deleting WEATHER_202307041720.csv
# Deleting WEATHER_202307041725.csv
# Deleting WEATHER_202307041730.csv
# Deleting WEATHER_202307041735.csv
# Deleting WEATHER_202307041740.csv
# Deleting WEATHER_202307041745.csv
# Deleting WEATHER_202307041750.csv
# Deleting WEATHER_202307041755.csv
# Deleting WEATHER_202307041805.csv
# Deleting WEATHER_202307041810.csv
# Deleting WEATHER_202307041815.csv
# Deleting WEATHER_202307041820.csv
# Deleting WEATHER_202307041825.csv
# Deleting WEATHER_202307041830.csv
# Deleting WEATHER_202307041835.csv
# Deleting WEATHER_202307041840.csv
# Deleting WEATHER_202307041845.csv
# Deleting WEATHER_202307041850.csv
# Deleting WEATHER_202307041855.csv
# Deleting WEATHER_202307041905.csv
# Deleting WEATHER_202307041910.csv
# Deleting WEATHER_202307041915.csv
# Deleting WEATHER_202307041920.csv
# Deleting WEATHER_202307041925.csv
# Deleting WEATHER_202307041930.csv
# Deleting WEATHER_202307041935.csv
# Deleting WEATHER_202307041940.csv
# Deleting WEATHER_202307041945.csv
# Deleting WEATHER_202307041950.csv
# Deleting WEATHER_202307041955.csv
# Deleting WEATHER_202307042005.csv
# Deleting WEATHER_202307042010.csv
# Deleting WEATHER_202307042015.csv
# Deleting WEATHER_202307042020.csv
# Deleting WEATHER_202307042025.csv
# Deleting WEATHER_202307042030.csv
# Deleting WEATHER_202307042035.csv
# Deleting WEATHER_202307042040.csv
# Deleting WEATHER_202307042045.csv
# Deleting WEATHER_202307042050.csv
# Deleting WEATHER_202307042055.csv
# Deleting WEATHER_202307042105.csv
# Deleting WEATHER_202307042110.csv
# Deleting WEATHER_202307042115.csv
# Deleting WEATHER_202307042120.csv
# Deleting WEATHER_202307042125.csv
# Deleting WEATHER_202307042130.csv
# Deleting WEATHER_202307042135.csv
# Deleting WEATHER_202307042140.csv
# Deleting WEATHER_202307042145.csv
# Deleting WEATHER_202307042150.csv
# Deleting WEATHER_202307042155.csv
# Deleting WEATHER_202307042205.csv
# Deleting WEATHER_202307042210.csv
# Deleting WEATHER_202307042215.csv
# Deleting WEATHER_202307042220.csv
# Deleting WEATHER_202307042225.csv
# Deleting WEATHER_202307042230.csv
# Deleting WEATHER_202307042235.csv
# Deleting WEATHER_202307042240.csv
# Deleting WEATHER_202307042245.csv
# Deleting WEATHER_202307042250.csv
# Deleting WEATHER_202307042255.csv
# Deleting WEATHER_202307042305.csv
# Deleting WEATHER_202307042310.csv
# Deleting WEATHER_202307042315.csv
# Deleting WEATHER_202307042320.csv
# Deleting WEATHER_202307042325.csv
# Deleting WEATHER_202307042330.csv
# Deleting WEATHER_202307042335.csv
# Deleting WEATHER_202307042340.csv
# Deleting WEATHER_202307042345.csv
# Deleting WEATHER_202307042350.csv
# Deleting WEATHER_202307042355.csv
# Deleting WEATHER_202307050005.csv
# Deleting WEATHER_202307050010.csv
# Deleting WEATHER_202307050015.csv
# Deleting WEATHER_202307050020.csv
# Deleting WEATHER_202307050025.csv
# Deleting WEATHER_202307050030.csv
# Deleting WEATHER_202307050035.csv
# Deleting WEATHER_202307050040.csv
# Deleting WEATHER_202307050045.csv
# Deleting WEATHER_202307050050.csv
# Deleting WEATHER_202307050055.csv
# Deleting WEATHER_202307050105.csv
# Deleting WEATHER_202307050110.csv
# Deleting WEATHER_202307050115.csv
# Deleting WEATHER_202307050120.csv
# Deleting WEATHER_202307050125.csv
# Deleting WEATHER_202307050130.csv
# Deleting WEATHER_202307050135.csv
# Deleting WEATHER_202307050140.csv
# Deleting WEATHER_202307050145.csv
# Deleting WEATHER_202307050150.csv
# Deleting WEATHER_202307050155.csv
# Deleting WEATHER_202307050205.csv
# Deleting WEATHER_202307050210.csv
# Deleting WEATHER_202307050215.csv
# Deleting WEATHER_202307050220.csv
# Deleting WEATHER_202307050225.csv
# Deleting WEATHER_202307050230.csv
# Deleting WEATHER_202307050235.csv
# Deleting WEATHER_202307050240.csv
# Deleting WEATHER_202307050245.csv
# Deleting WEATHER_202307050250.csv
# Deleting WEATHER_202307050255.csv
# Deleting WEATHER_202307050305.csv
# Deleting WEATHER_202307050310.csv
# Deleting WEATHER_202307050315.csv
# Deleting WEATHER_202307050320.csv
# Deleting WEATHER_202307050325.csv
# Deleting WEATHER_202307050330.csv
# Deleting WEATHER_202307050335.csv
# Deleting WEATHER_202307050340.csv
# Deleting WEATHER_202307050345.csv
# Deleting WEATHER_202307050350.csv
# Deleting WEATHER_202307050355.csv
# Deleting WEATHER_202307050405.csv
# Deleting WEATHER_202307050410.csv
# Deleting WEATHER_202307050415.csv
# Deleting WEATHER_202307050420.csv
# Deleting WEATHER_202307050425.csv
# Deleting WEATHER_202307050430.csv
# Deleting WEATHER_202307050435.csv
# Deleting WEATHER_202307050440.csv
# Deleting WEATHER_202307050445.csv
# Deleting WEATHER_202307050450.csv
# Deleting WEATHER_202307050455.csv
# Deleting WEATHER_202307050505.csv
# Deleting WEATHER_202307050510.csv
# Deleting WEATHER_202307050515.csv
# Deleting WEATHER_202307050520.csv
# Deleting WEATHER_202307050525.csv
# Deleting WEATHER_202307050530.csv
# Deleting WEATHER_202307050535.csv
# Deleting WEATHER_202307050540.csv
# Deleting WEATHER_202307050545.csv
# Deleting WEATHER_202307050550.csv
# Deleting WEATHER_202307050555.csv
# Deleting WEATHER_202307050605.csv
# Deleting WEATHER_202307050610.csv
# Deleting WEATHER_202307050615.csv
# Deleting WEATHER_202307050620.csv
# Deleting WEATHER_202307050625.csv
# Deleting WEATHER_202307050630.csv
# Deleting WEATHER_202307050635.csv
# Deleting WEATHER_202307050640.csv
# Deleting WEATHER_202307050645.csv
# Deleting WEATHER_202307050650.csv
# Deleting WEATHER_202307050655.csv
# Deleting WEATHER_202307050705.csv
# Deleting WEATHER_202307050710.csv
# Deleting WEATHER_202307050715.csv
# Deleting WEATHER_202307050720.csv
# Deleting WEATHER_202307050725.csv
# Deleting WEATHER_202307050730.csv
# Deleting WEATHER_202307050735.csv
# Deleting WEATHER_202307050740.csv
# Deleting WEATHER_202307050745.csv
# Deleting WEATHER_202307050750.csv
# Deleting WEATHER_202307050755.csv
# Deleting WEATHER_202307050805.csv
# Deleting WEATHER_202307050810.csv
# Deleting WEATHER_202307050815.csv
# Deleting WEATHER_202307050820.csv
# Deleting WEATHER_202307050825.csv
# Deleting WEATHER_202307050830.csv
# Deleting WEATHER_202307050835.csv
# Deleting WEATHER_202307050840.csv
# Deleting WEATHER_202307050845.csv
# Deleting WEATHER_202307050850.csv
# Deleting WEATHER_202307050855.csv
# Deleting WEATHER_202307050905.csv
# Deleting WEATHER_202307050910.csv
# Deleting WEATHER_202307050915.csv
# Deleting WEATHER_202307050920.csv
# Deleting WEATHER_202307050925.csv
# Deleting WEATHER_202307050930.csv
# Deleting WEATHER_202307050935.csv
# Deleting WEATHER_202307050940.csv
# Deleting WEATHER_202307050945.csv
# Deleting WEATHER_202307050950.csv
# Deleting WEATHER_202307050955.csv
# Deleting WEATHER_202307051005.csv
# Deleting WEATHER_202307051010.csv
# Deleting WEATHER_202307051015.csv
# Deleting WEATHER_202307051020.csv
# Deleting WEATHER_202307051025.csv
# Deleting WEATHER_202307051030.csv
# Deleting WEATHER_202307051035.csv
# Deleting WEATHER_202307051040.csv
# Deleting WEATHER_202307051045.csv
# Deleting WEATHER_202307051050.csv
# Deleting WEATHER_202307051055.csv
# Deleting WEATHER_202307051105.csv
# Deleting WEATHER_202307051110.csv
# Deleting WEATHER_202307051115.csv
# Deleting WEATHER_202307051120.csv
# Deleting WEATHER_202307051125.csv
# Deleting WEATHER_202307051130.csv
# Deleting WEATHER_202307051135.csv
# Deleting WEATHER_202307051140.csv
# Deleting WEATHER_202307051145.csv
# Deleting WEATHER_202307051150.csv
# Deleting WEATHER_202307051155.csv
# Deleting WEATHER_202307051205.csv
# Deleting WEATHER_202307051210.csv
# Deleting WEATHER_202307051215.csv
# Deleting WEATHER_202307051220.csv
# Deleting WEATHER_202307051225.csv
# Deleting WEATHER_202307051230.csv
# Deleting WEATHER_202307051235.csv
# Deleting WEATHER_202307051240.csv
# Deleting WEATHER_202307051245.csv
# Deleting WEATHER_202307051250.csv
# Deleting WEATHER_202307051255.csv
# Deleting WEATHER_202307051305.csv
# Deleting WEATHER_202307051310.csv
# Deleting WEATHER_202307051315.csv
# Deleting WEATHER_202307051320.csv
# Deleting WEATHER_202307051325.csv
# Deleting WEATHER_202307051330.csv
# Deleting WEATHER_202307051335.csv
# Deleting WEATHER_202307051340.csv
# Deleting WEATHER_202307051345.csv
# Deleting WEATHER_202307051350.csv
# Deleting WEATHER_202307051355.csv
# Deleting WEATHER_202307051405.csv
# Deleting WEATHER_202307051410.csv
# Deleting WEATHER_202307051415.csv
# Deleting WEATHER_202307051420.csv
# Deleting WEATHER_202307051425.csv
# Deleting WEATHER_202307051430.csv
# Deleting WEATHER_202307051435.csv
# Deleting WEATHER_202307051440.csv
# Deleting WEATHER_202307051445.csv
# Deleting WEATHER_202307051450.csv
# Deleting WEATHER_202307051455.csv
# Deleting WEATHER_202307051505.csv
# Deleting WEATHER_202307051510.csv
# Deleting WEATHER_202307051515.csv
# Deleting WEATHER_202307051520.csv
# Deleting WEATHER_202307051525.csv
# Deleting WEATHER_202307051530.csv
# Deleting WEATHER_202307051535.csv
# Deleting WEATHER_202307051540.csv
# Deleting WEATHER_202307051545.csv
# Deleting WEATHER_202307051550.csv
# Deleting WEATHER_202307051555.csv
# Deleting WEATHER_202307051605.csv
# Deleting WEATHER_202307051610.csv
# Deleting WEATHER_202307051615.csv
# Deleting WEATHER_202307051620.csv
# Deleting WEATHER_202307051625.csv
# Deleting WEATHER_202307051630.csv
# Deleting WEATHER_202307051635.csv
# Deleting WEATHER_202307051640.csv
# Deleting WEATHER_202307051645.csv
# Deleting WEATHER_202307051650.csv
# Deleting WEATHER_202307051655.csv
# Deleting WEATHER_202307051705.csv
# Deleting WEATHER_202307051710.csv
# Deleting WEATHER_202307051715.csv
# Deleting WEATHER_202307051720.csv
# Deleting WEATHER_202307051725.csv
# Deleting WEATHER_202307051730.csv
# Deleting WEATHER_202307051735.csv
# Deleting WEATHER_202307051740.csv
# Deleting WEATHER_202307051745.csv
# Deleting WEATHER_202307051750.csv
# Deleting WEATHER_202307051755.csv
# Deleting WEATHER_202307051805.csv
# Deleting WEATHER_202307051810.csv
# Deleting WEATHER_202307051815.csv
# Deleting WEATHER_202307051820.csv
# Deleting WEATHER_202307051825.csv
# Deleting WEATHER_202307051830.csv
# Deleting WEATHER_202307051835.csv
# Deleting WEATHER_202307051840.csv
# Deleting WEATHER_202307051845.csv
# Deleting WEATHER_202307051850.csv
# Deleting WEATHER_202307051855.csv
# Deleting WEATHER_202307051905.csv
# Deleting WEATHER_202307051910.csv
# Deleting WEATHER_202307051915.csv
# Deleting WEATHER_202307051920.csv
# Deleting WEATHER_202307051925.csv
# Deleting WEATHER_202307051930.csv
# Deleting WEATHER_202307051935.csv
# Deleting WEATHER_202307051940.csv
# Deleting WEATHER_202307051945.csv
# Deleting WEATHER_202307051950.csv
# Deleting WEATHER_202307051955.csv
# Deleting WEATHER_202307052005.csv
# Deleting WEATHER_202307052010.csv
# Deleting WEATHER_202307052015.csv
# Deleting WEATHER_202307052020.csv
# Deleting WEATHER_202307052025.csv
# Deleting WEATHER_202307052030.csv
# Deleting WEATHER_202307052035.csv
# Deleting WEATHER_202307052040.csv
# Deleting WEATHER_202307052045.csv
# Deleting WEATHER_202307052050.csv
# Deleting WEATHER_202307052055.csv
# Deleting WEATHER_202307052105.csv
# Deleting WEATHER_202307052110.csv
# Deleting WEATHER_202307052115.csv
# Deleting WEATHER_202307052120.csv
# Deleting WEATHER_202307052125.csv
# Deleting WEATHER_202307052130.csv
# Deleting WEATHER_202307052135.csv
# Deleting WEATHER_202307052140.csv
# Deleting WEATHER_202307052145.csv
# Deleting WEATHER_202307052150.csv
# Deleting WEATHER_202307052155.csv
# Deleting WEATHER_202307052205.csv
# Deleting WEATHER_202307052210.csv
# Deleting WEATHER_202307052215.csv
# Deleting WEATHER_202307052220.csv
# Deleting WEATHER_202307052225.csv
# Deleting WEATHER_202307052230.csv
# Deleting WEATHER_202307052235.csv
# Deleting WEATHER_202307052240.csv
# Deleting WEATHER_202307052245.csv
# Deleting WEATHER_202307052250.csv
# Deleting WEATHER_202307052255.csv
# Deleting WEATHER_202307052305.csv
# Deleting WEATHER_202307052310.csv
# Deleting WEATHER_202307052315.csv
# Deleting WEATHER_202307052320.csv
# Deleting WEATHER_202307052325.csv
# Deleting WEATHER_202307052330.csv
# Deleting WEATHER_202307052335.csv
# Deleting WEATHER_202307052340.csv
# Deleting WEATHER_202307052345.csv
# Deleting WEATHER_202307052350.csv
# Deleting WEATHER_202307052355.csv
# Deleting WEATHER_202307060005.csv
# Deleting WEATHER_202307060010.csv
# Deleting WEATHER_202307060015.csv
# Deleting WEATHER_202307060020.csv
# Deleting WEATHER_202307060025.csv
# Deleting WEATHER_202307060030.csv
# Deleting WEATHER_202307060035.csv
# Deleting WEATHER_202307060040.csv
# Deleting WEATHER_202307060045.csv
# Deleting WEATHER_202307060050.csv
# Deleting WEATHER_202307060055.csv
# Deleting WEATHER_202307060105.csv
# Deleting WEATHER_202307060110.csv
# Deleting WEATHER_202307060115.csv
# Deleting WEATHER_202307060120.csv
# Deleting WEATHER_202307060125.csv
# Deleting WEATHER_202307060130.csv
# Deleting WEATHER_202307060135.csv
# Deleting WEATHER_202307060140.csv
# Deleting WEATHER_202307060145.csv
# Deleting WEATHER_202307060150.csv
# Deleting WEATHER_202307060155.csv
# Deleting WEATHER_202307060205.csv
# Deleting WEATHER_202307060210.csv
# Deleting WEATHER_202307060215.csv
# Deleting WEATHER_202307060220.csv
# Deleting WEATHER_202307060225.csv
# Deleting WEATHER_202307060230.csv
# Deleting WEATHER_202307060235.csv
# Deleting WEATHER_202307060240.csv
# Deleting WEATHER_202307060245.csv
# Deleting WEATHER_202307060250.csv
# Deleting WEATHER_202307060255.csv
# Deleting WEATHER_202307060305.csv
# Deleting WEATHER_202307060310.csv
# Deleting WEATHER_202307060315.csv
# Deleting WEATHER_202307060320.csv
# Deleting WEATHER_202307060325.csv
# Deleting WEATHER_202307060330.csv
# Deleting WEATHER_202307060335.csv
# Deleting WEATHER_202307060340.csv
# Deleting WEATHER_202307060345.csv
# Deleting WEATHER_202307060350.csv
# Deleting WEATHER_202307060355.csv
# Deleting WEATHER_202307060405.csv
# Deleting WEATHER_202307060410.csv
# Deleting WEATHER_202307060415.csv
# Deleting WEATHER_202307060420.csv
# Deleting WEATHER_202307060425.csv
# Deleting WEATHER_202307060430.csv
# Deleting WEATHER_202307060435.csv
# Deleting WEATHER_202307060440.csv
# Deleting WEATHER_202307060445.csv
# Deleting WEATHER_202307060450.csv
# Deleting WEATHER_202307060455.csv
# Deleting WEATHER_202307060505.csv
# Deleting WEATHER_202307060510.csv
# Deleting WEATHER_202307060515.csv
# Deleting WEATHER_202307060520.csv
# Deleting WEATHER_202307060525.csv
# Deleting WEATHER_202307060530.csv
# Deleting WEATHER_202307060535.csv
# Deleting WEATHER_202307060540.csv
# Deleting WEATHER_202307060545.csv
# Deleting WEATHER_202307060550.csv
# Deleting WEATHER_202307060555.csv
# Deleting WEATHER_202307060605.csv
# Deleting WEATHER_202307060610.csv
# Deleting WEATHER_202307060615.csv
# Deleting WEATHER_202307060620.csv
# Deleting WEATHER_202307060625.csv
# Deleting WEATHER_202307060630.csv
# Deleting WEATHER_202307060635.csv
# Deleting WEATHER_202307060640.csv
# Deleting WEATHER_202307060645.csv
# Deleting WEATHER_202307060650.csv
# Deleting WEATHER_202307060655.csv
# Deleting WEATHER_202307060705.csv
# Deleting WEATHER_202307060710.csv
# Deleting WEATHER_202307060715.csv
# Deleting WEATHER_202307060720.csv
# Deleting WEATHER_202307060725.csv
# Deleting WEATHER_202307060730.csv
# Deleting WEATHER_202307060735.csv
# Deleting WEATHER_202307060740.csv
# Deleting WEATHER_202307060745.csv
# Deleting WEATHER_202307060750.csv
# Deleting WEATHER_202307060755.csv
# Deleting WEATHER_202307060805.csv
# Deleting WEATHER_202307060810.csv
# Deleting WEATHER_202307060815.csv
# ...
# Deleting WEATHER_202307300520.csv
# Deleting WEATHER_202307300525.csv
# Deleting WEATHER_202307300530.csv
# Deleting WEATHER_202307300535.csv
# Deleting WEATHER_202307300540.csv
# Deleting WEATHER_202307300545.csv
# Deleting WEATHER_202307300550.csv
# Deleting WEATHER_202307300555.csv
# Deleting WEATHER_202307300605.csv
# Deleting WEATHER_202307300610.csv
# Deleting WEATHER_202307300615.csv
# Deleting WEATHER_202307300620.csv
# Deleting WEATHER_202307300625.csv
# Deleting WEATHER_202307300630.csv
# Deleting WEATHER_202307300635.csv
# Deleting WEATHER_202307300640.csv
# Deleting WEATHER_202307300645.csv
# Deleting WEATHER_202307300650.csv
# Deleting WEATHER_202307300655.csv
# Deleting WEATHER_202307300705.csv
# Deleting WEATHER_202307300710.csv
# Deleting WEATHER_202307300715.csv
# Deleting WEATHER_202307300720.csv
# Deleting WEATHER_202307300725.csv
# Deleting WEATHER_202307300730.csv
# Deleting WEATHER_202307300735.csv
# Deleting WEATHER_202307300740.csv
# Deleting WEATHER_202307300745.csv
# Deleting WEATHER_202307300750.csv
# Deleting WEATHER_202307300755.csv
# Deleting WEATHER_202307300805.csv
# Deleting WEATHER_202307300810.csv
# Deleting WEATHER_202307300815.csv
# Deleting WEATHER_202307300820.csv
# Deleting WEATHER_202307300825.csv
# Deleting WEATHER_202307300830.csv
# Deleting WEATHER_202307300835.csv
# Deleting WEATHER_202307300840.csv
# Deleting WEATHER_202307300845.csv
# Deleting WEATHER_202307300850.csv
# Deleting WEATHER_202307300855.csv
# Deleting WEATHER_202307300905.csv
# Deleting WEATHER_202307300910.csv
# Deleting WEATHER_202307300915.csv
# Deleting WEATHER_202307300920.csv
# Deleting WEATHER_202307300925.csv
# Deleting WEATHER_202307300930.csv
# Deleting WEATHER_202307300935.csv
# Deleting WEATHER_202307300940.csv
# Deleting WEATHER_202307300945.csv
# Deleting WEATHER_202307300950.csv
# Deleting WEATHER_202307300955.csv
# Deleting WEATHER_202307301005.csv
# Deleting WEATHER_202307301010.csv
# Deleting WEATHER_202307301015.csv
# Deleting WEATHER_202307301020.csv
# Deleting WEATHER_202307301025.csv
# Deleting WEATHER_202307301030.csv
# Deleting WEATHER_202307301035.csv
# Deleting WEATHER_202307301040.csv
# Deleting WEATHER_202307301045.csv
# Deleting WEATHER_202307301050.csv
# Deleting WEATHER_202307301055.csv
# Deleting WEATHER_202307301105.csv
# Deleting WEATHER_202307301110.csv
# Deleting WEATHER_202307301115.csv
# Deleting WEATHER_202307301120.csv
# Deleting WEATHER_202307301125.csv
# Deleting WEATHER_202307301130.csv
# Deleting WEATHER_202307301135.csv
# Deleting WEATHER_202307301140.csv
# Deleting WEATHER_202307301145.csv
# Deleting WEATHER_202307301150.csv
# Deleting WEATHER_202307301155.csv
# Deleting WEATHER_202307301205.csv
# Deleting WEATHER_202307301210.csv
# Deleting WEATHER_202307301215.csv
# Deleting WEATHER_202307301220.csv
# Deleting WEATHER_202307301225.csv
# Deleting WEATHER_202307301230.csv
# Deleting WEATHER_202307301235.csv
# Deleting WEATHER_202307301240.csv
# Deleting WEATHER_202307301245.csv
# Deleting WEATHER_202307301250.csv
# Deleting WEATHER_202307301255.csv
# Deleting WEATHER_202307301305.csv
# Deleting WEATHER_202307301310.csv
# Deleting WEATHER_202307301315.csv
# Deleting WEATHER_202307301320.csv
# Deleting WEATHER_202307301325.csv
# Deleting WEATHER_202307301330.csv
# Deleting WEATHER_202307301335.csv
# Deleting WEATHER_202307301340.csv
# Deleting WEATHER_202307301345.csv
# Deleting WEATHER_202307301350.csv
# Deleting WEATHER_202307301355.csv
# Deleting WEATHER_202307301405.csv
# Deleting WEATHER_202307301410.csv
# Deleting WEATHER_202307301415.csv
# Deleting WEATHER_202307301420.csv
# Deleting WEATHER_202307301425.csv
# Deleting WEATHER_202307301430.csv
# Deleting WEATHER_202307301435.csv
# Deleting WEATHER_202307301440.csv
# Deleting WEATHER_202307301445.csv
# Deleting WEATHER_202307301450.csv
# Deleting WEATHER_202307301455.csv
# Deleting WEATHER_202307301505.csv
# Deleting WEATHER_202307301510.csv
# Deleting WEATHER_202307301515.csv
# Deleting WEATHER_202307301520.csv
# Deleting WEATHER_202307301525.csv
# Deleting WEATHER_202307301530.csv
# Deleting WEATHER_202307301535.csv
# Deleting WEATHER_202307301540.csv
# Deleting WEATHER_202307301545.csv
# Deleting WEATHER_202307301550.csv
# Deleting WEATHER_202307301555.csv
# Deleting WEATHER_202307301605.csv
# Deleting WEATHER_202307301610.csv
# Deleting WEATHER_202307301615.csv
# Deleting WEATHER_202307301620.csv
# Deleting WEATHER_202307301625.csv
# Deleting WEATHER_202307301630.csv
# Deleting WEATHER_202307301635.csv
# Deleting WEATHER_202307301640.csv
# Deleting WEATHER_202307301645.csv
# Deleting WEATHER_202307301650.csv
# Deleting WEATHER_202307301655.csv
# Deleting WEATHER_202307301705.csv
# Deleting WEATHER_202307301710.csv
# Deleting WEATHER_202307301715.csv
# Deleting WEATHER_202307301720.csv
# Deleting WEATHER_202307301725.csv
# Deleting WEATHER_202307301730.csv
# Deleting WEATHER_202307301735.csv
# Deleting WEATHER_202307301740.csv
# Deleting WEATHER_202307301745.csv
# Deleting WEATHER_202307301750.csv
# Deleting WEATHER_202307301755.csv
# Deleting WEATHER_202307301805.csv
# Deleting WEATHER_202307301810.csv
# Deleting WEATHER_202307301815.csv
# Deleting WEATHER_202307301820.csv
# Deleting WEATHER_202307301825.csv
# Deleting WEATHER_202307301830.csv
# Deleting WEATHER_202307301835.csv
# Deleting WEATHER_202307301840.csv
# Deleting WEATHER_202307301845.csv
# Deleting WEATHER_202307301850.csv
# Deleting WEATHER_202307301855.csv
# Deleting WEATHER_202307301905.csv
# Deleting WEATHER_202307301910.csv
# Deleting WEATHER_202307301915.csv
# Deleting WEATHER_202307301920.csv
# Deleting WEATHER_202307301925.csv
# Deleting WEATHER_202307301930.csv
# Deleting WEATHER_202307301935.csv
# Deleting WEATHER_202307301940.csv
# Deleting WEATHER_202307301945.csv
# Deleting WEATHER_202307301950.csv
# Deleting WEATHER_202307301955.csv
# Deleting WEATHER_202307302005.csv
# Deleting WEATHER_202307302010.csv
# Deleting WEATHER_202307302015.csv
# Deleting WEATHER_202307302020.csv
# Deleting WEATHER_202307302025.csv
# Deleting WEATHER_202307302030.csv
# Deleting WEATHER_202307302035.csv
# Deleting WEATHER_202307302040.csv
# Deleting WEATHER_202307302045.csv
# Deleting WEATHER_202307302050.csv
# Deleting WEATHER_202307302055.csv
# Deleting WEATHER_202307302105.csv
# Deleting WEATHER_202307302110.csv
# Deleting WEATHER_202307302115.csv
# Deleting WEATHER_202307302120.csv
# Deleting WEATHER_202307302125.csv
# Deleting WEATHER_202307302130.csv
# Deleting WEATHER_202307302135.csv
# Deleting WEATHER_202307302140.csv
# Deleting WEATHER_202307302145.csv
# Deleting WEATHER_202307302150.csv
# Deleting WEATHER_202307302155.csv
# Deleting WEATHER_202307302205.csv
# Deleting WEATHER_202307302210.csv
# Deleting WEATHER_202307302215.csv
# Deleting WEATHER_202307302220.csv
# Deleting WEATHER_202307302225.csv
# Deleting WEATHER_202307302230.csv
# Deleting WEATHER_202307302235.csv
# Deleting WEATHER_202307302240.csv
# Deleting WEATHER_202307302245.csv
# Deleting WEATHER_202307302250.csv
# Deleting WEATHER_202307302255.csv
# Deleting WEATHER_202307302305.csv
# Deleting WEATHER_202307302310.csv
# Deleting WEATHER_202307302315.csv
# Deleting WEATHER_202307302320.csv
# Deleting WEATHER_202307302325.csv
# Deleting WEATHER_202307302330.csv
# Deleting WEATHER_202307302335.csv
# Deleting WEATHER_202307302340.csv
# Deleting WEATHER_202307302345.csv
# Deleting WEATHER_202307302350.csv
# Deleting WEATHER_202307302355.csv
# Deleting WEATHER_202307310005.csv
# Deleting WEATHER_202307310010.csv
# Deleting WEATHER_202307310015.csv
# Deleting WEATHER_202307310020.csv
# Deleting WEATHER_202307310025.csv
# Deleting WEATHER_202307310030.csv
# Deleting WEATHER_202307310035.csv
# Deleting WEATHER_202307310040.csv
# Deleting WEATHER_202307310045.csv
# Deleting WEATHER_202307310050.csv
# Deleting WEATHER_202307310055.csv
# Deleting WEATHER_202307310105.csv
# Deleting WEATHER_202307310110.csv
# Deleting WEATHER_202307310115.csv
# Deleting WEATHER_202307310120.csv
# Deleting WEATHER_202307310125.csv
# Deleting WEATHER_202307310130.csv
# Deleting WEATHER_202307310135.csv
# Deleting WEATHER_202307310140.csv
# Deleting WEATHER_202307310145.csv
# Deleting WEATHER_202307310150.csv
# Deleting WEATHER_202307310155.csv
# Deleting WEATHER_202307310205.csv
# Deleting WEATHER_202307310210.csv
# Deleting WEATHER_202307310215.csv
# Deleting WEATHER_202307310220.csv
# Deleting WEATHER_202307310225.csv
# Deleting WEATHER_202307310230.csv
# Deleting WEATHER_202307310235.csv
# Deleting WEATHER_202307310240.csv
# Deleting WEATHER_202307310245.csv
# Deleting WEATHER_202307310250.csv
# Deleting WEATHER_202307310255.csv
# Deleting WEATHER_202307310305.csv
# Deleting WEATHER_202307310310.csv
# Deleting WEATHER_202307310315.csv
# Deleting WEATHER_202307310320.csv
# Deleting WEATHER_202307310325.csv
# Deleting WEATHER_202307310330.csv
# Deleting WEATHER_202307310335.csv
# Deleting WEATHER_202307310340.csv
# Deleting WEATHER_202307310345.csv
# Deleting WEATHER_202307310350.csv
# Deleting WEATHER_202307310355.csv
# Deleting WEATHER_202307310405.csv
# Deleting WEATHER_202307310410.csv
# Deleting WEATHER_202307310415.csv
# Deleting WEATHER_202307310420.csv
# Deleting WEATHER_202307310425.csv
# Deleting WEATHER_202307310430.csv
# Deleting WEATHER_202307310435.csv
# Deleting WEATHER_202307310440.csv
# Deleting WEATHER_202307310445.csv
# Deleting WEATHER_202307310450.csv
# Deleting WEATHER_202307310455.csv
# Deleting WEATHER_202307310505.csv
# Deleting WEATHER_202307310510.csv
# Deleting WEATHER_202307310515.csv
# Deleting WEATHER_202307310520.csv
# Deleting WEATHER_202307310525.csv
# Deleting WEATHER_202307310530.csv
# Deleting WEATHER_202307310535.csv
# Deleting WEATHER_202307310540.csv
# Deleting WEATHER_202307310545.csv
# Deleting WEATHER_202307310550.csv
# Deleting WEATHER_202307310555.csv
# Deleting WEATHER_202307310605.csv
# Deleting WEATHER_202307310610.csv
# Deleting WEATHER_202307310615.csv
# Deleting WEATHER_202307310620.csv
# Deleting WEATHER_202307310625.csv
# Deleting WEATHER_202307310630.csv
# Deleting WEATHER_202307310635.csv
# Deleting WEATHER_202307310640.csv
# Deleting WEATHER_202307310645.csv
# Deleting WEATHER_202307310650.csv
# Deleting WEATHER_202307310655.csv
# Deleting WEATHER_202307310705.csv
# Deleting WEATHER_202307310710.csv
# Deleting WEATHER_202307310715.csv
# Deleting WEATHER_202307310720.csv
# Deleting WEATHER_202307310725.csv
# Deleting WEATHER_202307310730.csv
# Deleting WEATHER_202307310735.csv
# Deleting WEATHER_202307310740.csv
# Deleting WEATHER_202307310745.csv
# Deleting WEATHER_202307310750.csv
# Deleting WEATHER_202307310755.csv
# Deleting WEATHER_202307310805.csv
# Deleting WEATHER_202307310810.csv
# Deleting WEATHER_202307310815.csv
# Deleting WEATHER_202307310820.csv
# Deleting WEATHER_202307310825.csv
# Deleting WEATHER_202307310830.csv
# Deleting WEATHER_202307310835.csv
# Deleting WEATHER_202307310840.csv
# Deleting WEATHER_202307310845.csv
# Deleting WEATHER_202307310850.csv
# Deleting WEATHER_202307310855.csv
# Deleting WEATHER_202307310905.csv
# Deleting WEATHER_202307310910.csv
# Deleting WEATHER_202307310915.csv
# Deleting WEATHER_202307310920.csv
# Deleting WEATHER_202307310925.csv
# Deleting WEATHER_202307310930.csv
# Deleting WEATHER_202307310935.csv
# Deleting WEATHER_202307310940.csv
# Deleting WEATHER_202307310945.csv
# Deleting WEATHER_202307310950.csv
# Deleting WEATHER_202307310955.csv
# Deleting WEATHER_202307311005.csv
# Deleting WEATHER_202307311010.csv
# Deleting WEATHER_202307311015.csv
# Deleting WEATHER_202307311020.csv
# Deleting WEATHER_202307311025.csv
# Deleting WEATHER_202307311030.csv
# Deleting WEATHER_202307311035.csv
# Deleting WEATHER_202307311040.csv
# Deleting WEATHER_202307311045.csv
# Deleting WEATHER_202307311050.csv
# Deleting WEATHER_202307311055.csv
# Deleting WEATHER_202307311105.csv
# Deleting WEATHER_202307311110.csv
# Deleting WEATHER_202307311115.csv
# Deleting WEATHER_202307311120.csv
# Deleting WEATHER_202307311125.csv
# Deleting WEATHER_202307311130.csv
# Deleting WEATHER_202307311135.csv
# Deleting WEATHER_202307311140.csv
# Deleting WEATHER_202307311145.csv
# Deleting WEATHER_202307311150.csv
# Deleting WEATHER_202307311155.csv
# Deleting WEATHER_202307311205.csv
# Deleting WEATHER_202307311210.csv
# Deleting WEATHER_202307311215.csv
# Deleting WEATHER_202307311220.csv
# Deleting WEATHER_202307311225.csv
# Deleting WEATHER_202307311230.csv
# Deleting WEATHER_202307311235.csv
# Deleting WEATHER_202307311240.csv
# Deleting WEATHER_202307311245.csv
# Deleting WEATHER_202307311250.csv
# Deleting WEATHER_202307311255.csv
# Deleting WEATHER_202307311305.csv
# Deleting WEATHER_202307311310.csv
# Deleting WEATHER_202307311315.csv
# Deleting WEATHER_202307311320.csv
# Deleting WEATHER_202307311325.csv
# Deleting WEATHER_202307311330.csv
# Deleting WEATHER_202307311335.csv
# Deleting WEATHER_202307311340.csv
# Deleting WEATHER_202307311345.csv
# Deleting WEATHER_202307311350.csv
# Deleting WEATHER_202307311355.csv
# Deleting WEATHER_202307311405.csv
# Deleting WEATHER_202307311410.csv
# Deleting WEATHER_202307311415.csv
# Deleting WEATHER_202307311420.csv
# Deleting WEATHER_202307311425.csv
# Deleting WEATHER_202307311430.csv
# Deleting WEATHER_202307311435.csv
# Deleting WEATHER_202307311440.csv
# Deleting WEATHER_202307311445.csv
# Deleting WEATHER_202307311450.csv
# Deleting WEATHER_202307311455.csv
# Deleting WEATHER_202307311505.csv
# Deleting WEATHER_202307311510.csv
# Deleting WEATHER_202307311515.csv
# Deleting WEATHER_202307311520.csv
# Deleting WEATHER_202307311525.csv
# Deleting WEATHER_202307311530.csv
# Deleting WEATHER_202307311535.csv
# Deleting WEATHER_202307311540.csv
# Deleting WEATHER_202307311545.csv
# Deleting WEATHER_202307311550.csv
# Deleting WEATHER_202307311555.csv
# Deleting WEATHER_202307311605.csv
# Deleting WEATHER_202307311610.csv
# Deleting WEATHER_202307311615.csv
# Deleting WEATHER_202307311620.csv
# Deleting WEATHER_202307311625.csv
# Deleting WEATHER_202307311630.csv
# Deleting WEATHER_202307311635.csv
# Deleting WEATHER_202307311640.csv
# Deleting WEATHER_202307311645.csv
# Deleting WEATHER_202307311650.csv
# Deleting WEATHER_202307311655.csv
# Deleting WEATHER_202307311705.csv
# Deleting WEATHER_202307311710.csv
# Deleting WEATHER_202307311715.csv
# Deleting WEATHER_202307311720.csv
# Deleting WEATHER_202307311725.csv
# Deleting WEATHER_202307311730.csv
# Deleting WEATHER_202307311735.csv
# Deleting WEATHER_202307311740.csv
# Deleting WEATHER_202307311745.csv
# Deleting WEATHER_202307311750.csv
# Deleting WEATHER_202307311755.csv
# Deleting WEATHER_202307311805.csv
# Deleting WEATHER_202307311810.csv
# Deleting WEATHER_202307311815.csv
# Deleting WEATHER_202307311820.csv
# Deleting WEATHER_202307311825.csv
# Deleting WEATHER_202307311830.csv
# Deleting WEATHER_202307311835.csv
# Deleting WEATHER_202307311840.csv
# Deleting WEATHER_202307311845.csv
# Deleting WEATHER_202307311850.csv
# Deleting WEATHER_202307311855.csv
# Deleting WEATHER_202307311905.csv
# Deleting WEATHER_202307311910.csv
# Deleting WEATHER_202307311915.csv
# Deleting WEATHER_202307311920.csv
# Deleting WEATHER_202307311925.csv
# Deleting WEATHER_202307311930.csv
# Deleting WEATHER_202307311935.csv
# Deleting WEATHER_202307311940.csv
# Deleting WEATHER_202307311945.csv
# Deleting WEATHER_202307311950.csv
# Deleting WEATHER_202307311955.csv
# Deleting WEATHER_202307312005.csv
# Deleting WEATHER_202307312010.csv
# Deleting WEATHER_202307312015.csv
# Deleting WEATHER_202307312020.csv
# Deleting WEATHER_202307312025.csv
# Deleting WEATHER_202307312030.csv
# Deleting WEATHER_202307312035.csv
# Deleting WEATHER_202307312040.csv
# Deleting WEATHER_202307312045.csv
# Deleting WEATHER_202307312050.csv
# Deleting WEATHER_202307312055.csv
# Deleting WEATHER_202307312105.csv
# Deleting WEATHER_202307312110.csv
# Deleting WEATHER_202307312115.csv
# Deleting WEATHER_202307312120.csv
# Deleting WEATHER_202307312125.csv
# Deleting WEATHER_202307312130.csv
# Deleting WEATHER_202307312135.csv
# Deleting WEATHER_202307312140.csv
# Deleting WEATHER_202307312145.csv
# Deleting WEATHER_202307312150.csv
# Deleting WEATHER_202307312155.csv
# Deleting WEATHER_202307312205.csv
# Deleting WEATHER_202307312210.csv
# Deleting WEATHER_202307312215.csv
# Deleting WEATHER_202307312220.csv
# Deleting WEATHER_202307312225.csv
# Deleting WEATHER_202307312230.csv
# Deleting WEATHER_202307312235.csv
# Deleting WEATHER_202307312240.csv
# Deleting WEATHER_202307312245.csv
# Deleting WEATHER_202307312250.csv
# Deleting WEATHER_202307312255.csv
# Deleting WEATHER_202307312305.csv
# Deleting WEATHER_202307312310.csv
# Deleting WEATHER_202307312315.csv
# Deleting WEATHER_202307312320.csv
# Deleting WEATHER_202307312325.csv
# Deleting WEATHER_202307312330.csv
# Deleting WEATHER_202307312335.csv
# Deleting WEATHER_202307312340.csv
# Deleting WEATHER_202307312345.csv
# Deleting WEATHER_202307312350.csv
# Deleting WEATHER_202307312355.csv
# 압축파일 업데이트 완료!

# %%
import math

# -----------------------------------
# 상수 및 맵핑
# -----------------------------------
X0 = 700000
Y0 = 1300000
Unit100_000m = 100000
IDX08 = 8

# Java 코드에서 사용한 char[] Names = {'가', '나', '다', '라', '마', '바', '사', '아', 'a', 'b'};
Names = ['가', '나', '다', '라', '마', '바', '사', '아', 'a', 'b']

# Java의 hashNames 초기화 로직
hashNames = {}
k = 0
for i, ch in enumerate(Names):
    if i >= IDX08:
        # i=8부터 'a','b'에 대해 0,1 할당
        hashNames[ch] = k
        k += 1
    else:
        # i=0~7에 대해 '가'=0, '나'=1, ... '아'=7
        hashNames[ch] = i

# -----------------------------------
# (1) UTM-K → 500m 그리드 ID
# -----------------------------------
def nationalGridIDx500m(ux, uy):
    """
    UTM-K 좌표 (ux, uy)를 입력받아 500m 단위 그리드 ID를 생성한다.
    """
    # 1) 100km 단위
    unit = Unit100_000m

    xn = int(ux - X0)
    yn = int(uy - Y0)

    xn0 = xn // unit  # x축 100km 블록 인덱스
    yn0 = yn // unit  # y축 100km 블록 인덱스

    if xn0 < 0 or xn0 > 7 or yn0 < 0 or yn0 > 7:
        return None

    xn1 = xn - xn0 * unit  # 100km 블록 내부 x잔여
    yn1 = yn - yn0 * unit  # 100km 블록 내부 y잔여

    # 2) 1km 단위 (1000m)
    unit = unit // 100
    xr0 = xn1 // unit  # x축 1km 블록 인덱스
    yr0 = yn1 // unit  # y축 1km 블록 인덱스

    xn2 = xn1 - xr0 * unit  # 1km 블록 내부 x잔여
    yn2 = yn1 - yr0 * unit  # 1km 블록 내부 y잔여

    # 3) 500m 단위
    unit = unit // 2
    xr1 = xn2 // unit  # 500m 세분화(0 or 1)
    yr1 = yn2 // unit  # 500m 세분화(0 or 1)

    # 4) 그리드 ID 문자열 구성
    #    - 첫 2글자: 100km 인덱스 (가,나,다,라,마,바,사,아)
    #    - 그 뒤 2자리: 1km 인덱스
    #    - 500m: a or b
    #    - y축도 동일 구조
    result = []
    result.append(Names[xn0])   # ex) '다'
    result.append(Names[yn0])   # ex) '사'

    # x축 1km 인덱스 2자리
    if xr0 > 9:
        result.append(str(xr0))
    else:
        result.append("0")
        result.append(str(xr0))

    # 500m 인덱스 (a/b)
    result.append(Names[IDX08 + xr1])   # ex) a or b

    # y축 1km 인덱스 2자리
    if yr0 > 9:
        result.append(str(yr0))
    else:
        result.append("0")
        result.append(str(yr0))

    # 500m 인덱스 (a/b)
    result.append(Names[IDX08 + yr1])   # ex) a or b

    return "".join(result)

# -----------------------------------
# (2) 500m 그리드 ID → UTM-K
# -----------------------------------
def utmKFrom500mGridID(nationalID, center=False):
    """
    500m 단위 그리드 ID를 입력받아 UTM-K 좌표(x, y)를 반환한다.
    center=True 면 해당 500m 셀의 중앙좌표를 반환
    """
    # Java 코드는 정규식 패턴 검사(patterns[3]) 후 진행하지만,
    # 여기서는 단순 길이 체크나 생략 가능. 필요 시 re 모듈로 보강.
    if len(nationalID) != 8:
        raise ValueError(f"Invalid 500m Grid ID: {nationalID}")

    # 1) 100km 블록 인덱스
    xn0 = hashNames[nationalID[0]]  # '다'
    yn0 = hashNames[nationalID[1]]  # '사'

    # 2) 1km 단위
    unit_1km = Unit100_000m // 100
    xr0 = int(nationalID[2:4]) * unit_1km  # x축 1km
    yr0 = int(nationalID[5:7]) * unit_1km  # y축 1km

    # 3) 500m 단위
    unit_500m = unit_1km // 2
    xn1 = hashNames[nationalID[4]]  # 'a' or 'b' → 0 or 1
    yn1 = hashNames[nationalID[7]]  # 'a' or 'b' → 0 or 1

    x = X0 + Unit100_000m * xn0 + xr0 + xn1 * unit_500m
    y = Y0 + Unit100_000m * yn0 + yr0 + yn1 * unit_500m

    # 중심좌표를 원한다면 500m 절반(=250m)만큼 이동
    if center:
        x += unit_500m * 0.5
        y += unit_500m * 0.5

    return (x, y)

# -----------------------------------
# 간단 테스트
# -----------------------------------
if __name__ == "__main__":
    # 예: Java 코드에서 "다사54b44b" -> (x, y) 변환 후 다시 500m ID를 찍어보기
    grid_id = "나b75a78a"
    xy = utmKFrom500mGridID(grid_id, center=True)
    print(f"{grid_id} -> {xy}")

    # 다시 UTM-K -> 500m ID
    back_id = nationalGridIDx500m(xy[0], xy[1])
    print(f"{xy} -> {back_id}")
# Out:
# 나b75a78a -> (875250.0, 1478250.0)
# (875250.0, 1478250.0) -> 나나75a78a

# %%
from shapely.geometry import Point
from shapely import speedups

# Shapely speedups 활성화
if speedups.available:
    speedups.enable()

def create_prepared_dict(gdf):
    """
    GeoDataFrame의 인덱스와 'prep_geom' 열의 prepared geometry를 딕셔너리로 변환합니다.
    """
    return {idx: geom for idx, geom in zip(gdf.index, gdf['prep_geom'])}

def flagContains(utm_x, utm_y, prep_dict, sindex):
    """
    주어진 UTM 좌표 (utm_x, utm_y)가 공간 인덱스(sindex)를 활용해,
    딕셔너리(prep_dict)에 저장된 준비된(prepared) 지오메트리 중 하나에 포함되는지 검사합니다.
    """
    pt = Point(utm_x, utm_y)
    candidate_indexes = list(sindex.intersection(pt.bounds))
    for idx in candidate_indexes:
        # 딕셔너리에서 준비된 지오메트리를 빠르게 조회
        if prep_dict[idx].contains(pt):
            return True
    return False
# Out:
# C:\Users\chois\AppData\Local\Temp\ipykernel_16456\3403150244.py:6: DeprecationWarning: This function has no longer any effect, and will be removed in a future release. Starting with Shapely 2.0, equivalent speedups are always available
#   speedups.enable()

# %%
import zipfile
import csv
import io
import os
import tempfile
import shutil
from pyproj import CRS, Transformer

import pandas as pd
import geopandas as gpd
from shapely.prepared import prep


def add_gid_to_csv_in_zip(zip_path, output_zip_path=None, sido_path=None):
    """
    ZIP 파일 내부의 CSV 파일들을 읽어, 각 CSV 파일에 대해
    - lon, lat 값을 vectorized하게 UTM-K 좌표로 변환하고,
    - GeoPandas의 spatial join을 이용해 shapefile(행정구역) 내에 포함되는 점만 남긴 후,
    - 각 점에 대해 gid 값을 nationalGridIDx500m를 통해 생성하여 'gid' 열에 추가합니다.
    처리 후 결과 CSV 파일들을 새 ZIP 파일에 저장합니다.
    """
    crs_utmk_str = "+proj=tmerc +lat_0=38 +lon_0=127.5 +k=0.9996 +x_0=1000000 +y_0=2000000 +ellps=GRS80 +units=m +no_defs"

    # 행정구역 shapefile이 없으면 처리하지 않음
    if not sido_path:
        print("행정구역 shapefile이 주어지지 않았습니다. gid 필드를 추가하지 않습니다.")
        return

    sido_gdf = gpd.read_file(sido_path)
    
    if sido_gdf.crs is None:
        sido_gdf = sido_gdf.set_crs(crs_utmk_str, allow_override=True)
    else:
        sido_gdf = sido_gdf.to_crs(crs_utmk_str)

    # output_zip_path가 지정되지 않았다면, 임시 파일을 생성하고 이후 원본과 교체
    if not output_zip_path:
        tmp_fd, tmp_zip = tempfile.mkstemp(suffix='.zip')
        os.close(tmp_fd)
        output_zip_path = tmp_zip
        replace_original = True
    else:
        replace_original = False

    # 좌표 변환 설정: WGS84 -> UTM-K
    crs_wsg84 = CRS.from_epsg(4326)
    crs_utmk = CRS.from_proj4(crs_utmk_str)
    transformer = Transformer.from_crs(crs_wsg84, crs_utmk, always_xy=True)

    with zipfile.ZipFile(zip_path, 'r') as zip_in, \
         zipfile.ZipFile(output_zip_path, 'w') as zip_out:

        for item in zip_in.infolist():
            filename = item.filename
            print(f"Processing {filename}...")

            # CSV 파일 처리
            if filename.lower().endswith('.csv'):
                csv_data = zip_in.read(filename)
                text_data = csv_data.decode('utf-8', errors='replace')
                # pandas를 이용해 CSV를 읽음
                try:
                    df = pd.read_csv(io.StringIO(text_data))
                except Exception as e:
                    print(f"[ERROR] {filename} CSV 읽기 실패: {e}")
                    zip_out.writestr(filename, csv_data)
                    continue

                # lon, lat 열이 없는 경우 원본 그대로 기록
                if 'lon' not in df.columns or 'lat' not in df.columns:
                    print(f"[WARNING] '{filename}'에서 'lon' 또는 'lat' 열을 찾을 수 없습니다. 원본 그대로 복사합니다.")
                    zip_out.writestr(filename, csv_data)
                    continue

                # 좌표 변환: vectorized 처리
                try:
                    # 위경도 값들을 float로 변환 후 numpy arrays로 받음
                    lon_vals = df['lon'].astype(float).values
                    lat_vals = df['lat'].astype(float).values
                except Exception as e:
                    print(f"[ERROR] {filename}의 위경도 값 파싱 오류: {e}")
                    zip_out.writestr(filename, csv_data)
                    continue

                utm_x, utm_y = transformer.transform(lon_vals, lat_vals)

                # UTM 좌표를 기반으로 포인트 생성 (vectorized)
                gdf_points = gpd.GeoDataFrame(df, 
                                              geometry=gpd.points_from_xy(utm_x, utm_y),
                                              crs=crs_utmk.to_string())
                # 공간 조인을 통해, sido_gdf 내에 포함되는 점만 선택
                # sjoin은 좌표계가 동일해야 하므로, sido_gdf의 CRS가 UTM-K라고 가정합니다.
                try:
                    # inner join: 점이 polygon 내부에 있어야만 남김
                    joined = gpd.sjoin(gdf_points, sido_gdf, how='inner', predicate='within')
                except Exception as e:
                    print(f"[ERROR] {filename} spatial join 실패: {e}")
                    zip_out.writestr(filename, csv_data)
                    continue

                if joined.empty:
                    # 모든 점이 필터링되어 결과가 없으면, 빈 CSV 파일로 기록
                    new_csv = ""
                else:
                    # gid 값 생성: vectorized 또는 apply 방식으로 각 행에 대해 gid를 생성
                    joined['gid'] = joined.apply(lambda row: nationalGridIDx500m(row.geometry.x, row.geometry.y), axis=1)
                    # 필요한 열만 선택해서 CSV로 저장 (원본 열 순서를 유지하거나, 필요에 따라 조정)
                    # 여기서는 원본 df의 열 + 'gid'
                    # 만약 'gid' 열이 이미 존재했다면 덮어씌우게 됩니다.
                    output_cols = list(df.columns)
                    if 'gid' not in output_cols:
                        output_cols.append('gid')
                    # sjoin 결과에는 추가 정보(인덱스_right 등)가 있으므로, 선택적으로 제거
                    new_csv = joined[output_cols].to_csv(index=False)

                # 기록할 CSV 데이터를 bytes로 인코딩
                zip_out.writestr(filename, new_csv.encode('utf-8'))
            else:
                # CSV 외의 파일은 그대로 복사
                zip_out.writestr(filename, zip_in.read(filename))

    if replace_original:
        shutil.move(output_zip_path, zip_path)
        print(f"'{zip_path}'에 gid 필드가 추가된 버전을 덮어썼습니다.")
    else:
        print(f"'{zip_path}' -> '{output_zip_path}'로 gid 필드를 추가한 새 zip을 생성했습니다.")


def process_zip_files_in_folder(input_folder, sido_path, output_folder):
    # output 폴더가 존재하지 않으면 생성
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # input_folder 내의 모든 파일에 대해 반복
    for filename in os.listdir(input_folder):
        if filename.lower().endswith('.zip'):
            input_zip_path = os.path.join(input_folder, filename)
            base, ext = os.path.splitext(filename)
            new_filename = f"{base}_with_gid{ext}"
            output_zip_path = os.path.join(output_folder, new_filename)
            print(f"Processing {input_zip_path} -> {output_zip_path} ...")
            add_gid_to_csv_in_zip(input_zip_path, output_zip_path, sido_path)

# 사용 예시
if __name__ == "__main__":
    sido_path = "D:\\PROJECT\\2025\\01.CarbonMap\\01.Data\\03.행정구역\\sido_2023.shp"
    original_zip = "D:\\PROJECT\\2025\\01.CarbonMap\\01.Data\\02.Weather"               # 원본 ZIP 파일 경로
    updated_zip = "D:\\PROJECT\\2025\\01.CarbonMap\\01.Data\\02.Weather\\add_grid"      # gid 필드 추가 후 저장할 ZIP 파일 경로
    
    process_zip_files_in_folder(original_zip, sido_path, updated_zip)
    print("모든 작업이 완료되었습니다.")
# Out:
# Processing D:\PROJECT\2025\01.CarbonMap\01.Data\02.Weather\01_Weather_202301.zip -> D:\PROJECT\2025\01.CarbonMap\01.Data\02.Weather\add_grid\01_Weather_202301_with_gid.zip ...
# Processing WEATHER_202301010000.csv...
# Processing WEATHER_202301010100.csv...
# Processing WEATHER_202301010200.csv...
# Processing WEATHER_202301010300.csv...
# Processing WEATHER_202301010400.csv...
# Processing WEATHER_202301010500.csv...
# Processing WEATHER_202301010600.csv...
# Processing WEATHER_202301010700.csv...
# Processing WEATHER_202301010800.csv...
# Processing WEATHER_202301010900.csv...
# Processing WEATHER_202301011000.csv...
# Processing WEATHER_202301011100.csv...
# Processing WEATHER_202301011200.csv...
# Processing WEATHER_202301011300.csv...
# Processing WEATHER_202301011400.csv...
# Processing WEATHER_202301011500.csv...
# Processing WEATHER_202301011600.csv...
# Processing WEATHER_202301011700.csv...
# Processing WEATHER_202301011800.csv...
# Processing WEATHER_202301011900.csv...
# Processing WEATHER_202301012000.csv...
# Processing WEATHER_202301012100.csv...
# Processing WEATHER_202301012200.csv...
# Processing WEATHER_202301012300.csv...
# Processing WEATHER_202301020000.csv...
# Processing WEATHER_202301020100.csv...
# Processing WEATHER_202301020200.csv...
# Processing WEATHER_202301020300.csv...
# Processing WEATHER_202301020400.csv...
# Processing WEATHER_202301020500.csv...
# Processing WEATHER_202301020600.csv...
# Processing WEATHER_202301020700.csv...

# %%
from shapely.prepared import prep
from pyproj import CRS, Transformer
import geopandas as gpd

# 좌표 변환
crs_wsg84 = CRS.from_epsg(4326)
crs_utmk = CRS.from_proj4("+proj=tmerc +lat_0=38 +lon_0=127.5 +k=0.9996 + x_0=1000000 + y_0=2000000 + ellps=GRS80 +units=m +no_defs")
transformer = Transformer.from_crs(crs_wsg84, crs_utmk, always_xy=True)

lon, lat = 126.18531,31.484838
utm_x, utm_y = transformer.transform(lon, lat)
print(utm_x, utm_y)

print(nationalGridIDx500m(utm_x, utm_y))

sido_path = "D:\\PROJECT\\2025\\01.CarbonMap\\01.Data\\03.행정구역\\sido_2023.shp"
sido_gdf = gpd.read_file(sido_path)
# 각 폴리곤을 준비된 지오메트리로 변환 (속도 향상 효과)
sido_gdf["prep_geom"] = sido_gdf.geometry.apply(prep)
sindex = sido_gdf.sindex  # 공간 인덱스 생성

# 폴리곤 내부 포함 여부 검사하여 gid 결정
if flagContains(utm_x, utm_y, sido_gdf, sindex):
    gid_value = nationalGridIDx500m(utm_x, utm_y)
else:
    gid_value = None

print(gid_value)
# Out:
# 875126.1959198355 1278269.4860866773
# None
# None
